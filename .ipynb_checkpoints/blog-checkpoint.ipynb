# %% [markdown]
# # Storm Overflows in the South West: A Three-Scale Analysis of Sewage Spills on the Dart, the South West, and England
#
# The narrative writeup for this project is published at: [insert hackmd link here]
#
# This notebook contains all code used to produce the analysis and outputs.
#
# Note - cells falling under 'inspection cell' naming are solely inspection and should not themselves be necessary to the main code pipeline - simply used for decision making as the code was created (left in for reproducibity purposes and understanding the data and exactly why certain decisions were made). They can be ignored if desired.

# %% [markdown]
# ### Section 0 - Setup
#
# The cell below imports all libraries used in this notebook and sets some plot styles and output formatting.

# %%
import os # for interacting with the computer's file system e.g. to create folders or file paths for the correct OS (i.e. fixes / vs \ between mac/linux and windows)
import time # allows us to use things like time.sleep() later
import warnings # allows us to do things like suppressing warning messages (done later in this code block)
import zipfile # allows us to read and extract ZIP  files

import numpy as np # for numerical operations
import pandas as pd # necessary for data manipulation - dataframes used later are from this

import requests #  lets Python make HTTP requests (allows us to download data and query APIs later)

import matplotlib.pyplot as plt # library for python plotting
import matplotlib.ticker as mticker # allows for control of axis formatting
import seaborn as sns # a better python plotting library atop matplot (better looking plots ect.)
import folium # library for creating interacive maps (to use later to map sewage overflow locations)

import statsmodels.formula.api as smf  # for OLS regression at Scales 1, 2, and 3

import plotly.graph_objects as go  # for interactive charts with hover tooltips

from IPython.display import display # allows outputs (specifically dataframes) to be nicely formatted in outputs

warnings.filterwarnings('ignore') # suppresses some warning messages for minor problems (avoids messy outputs from unnecessary error messages)

sns.set_theme(style='whitegrid', font_scale=1.1) # sets global seaborn plot styling 
COLOUR_DART = '#1f6aa5'   # blue — used for Dart-specific highlights
COLOUR_SWW = '#e07b39'   # orange — used for other SWW rivers
COLOUR_NATIONAL = '#6c757d'   # grey — national/other companies

OUTPUTS_DIR = os.path.join('outputs')  # directory for saving chart output files
os.makedirs(OUTPUTS_DIR, exist_ok=True)  # creates the folder if it does not already exist

print('Setup complete.')
# Out:
# Setup complete.

# %% [markdown]
# ## Phase 1 - Data Collection
#
# > this phase downloads all data sources and fetches all rainfall figures from the EA Hydrology API
# > no analysis runs here - all outputs saved to data/raw/ or data/processed/
# > note: SWW catchment gauge fetch (section 3b) appears after catchment identification in Section 2 - this ordering is intentional

# %% [markdown]
# #### Helper Functions - compute_storm_days() and get_wfd_catchment_col()
#
# Two helper functions used throughout the notebook. `compute_storm_days()` averages daily readings across gauges before applying threshold. `get_wfd_catchment_col()` returns the correct WFD catchment column name for a given year - 2021–2023 use Cycle 2 naming, 2024 uses Cycle 3.

# %%
def compute_storm_days(daily_df, rain_col='rainfall_mm', thresholds=(10, 15, 20)):
    # ensures a day only counts as a storm day if the catchment average exceeded the threshold
    daily_avg = (daily_df.groupby(['date', 'year'])[rain_col].mean().reset_index())  # averages across gauges for each day

    records = []  # empty list to fill with one dictionary per year
    for year, group in daily_avg.groupby('year'):  # loops through each years daily data
        row = {'year': year}  # starts each years dictionary with just the year
        for t in thresholds:  # loops through each threshold
            row[f'storm_days_{t}'] = (group[rain_col] >= t).sum()  # sums the number of days where averaged rainfall met or exceeded the threshold
        records.append(row)  # adds the years dictionary to the records list

    return pd.DataFrame(records).sort_values('year').reset_index(drop=True)  # converts list of dictionaries to dataframe, sorted by year

# %%
def get_wfd_catchment_col(year):
    # returns the correct WFD catchment column name for a given year - 2021-2023 use cycle 2 naming, 2024 uses cycle 3 naming (confirmed in 2a inspection cells)
    if year == 2024:
        return 'WFD Waterbody Catchment Name (Cycle 3)\n(discharge outlet)'
    else:
        return 'WFD Waterbody Catchment Name (Cycle 2)\n(discharge outlet)'

# %% [markdown]
# ### Section 1a - Fetch EDM Storm Overflow Data
# Scales 1, 2, and 3 - downloads four years of EDM ZIP archives (2021–2024) from the EA's data portal. It extracts the two relevant Excel files per year to `data/raw/`. 2020 is excluded as its published as separate per-company files, structurally inconsistent with later years.

# %%
# creates dictionary mapping year to the URL where the zip folder holds that year's data
EDM_URLS = {
    2021: 'https://environment.data.gov.uk/api/file/download?fileDataSetId=c55e170e-3c75-49a5-8026-a961ff94c8e0&fileName=EDM_2021_Storm_Overflow_Annual_Return.zip',
    2022: 'https://environment.data.gov.uk/api/file/download?fileDataSetId=c55e170e-3c75-49a5-8026-a961ff94c8e0&fileName=EDM_2022_Storm_Overflow_Annual_Return.zip',
    2023: 'https://environment.data.gov.uk/api/file/download?fileDataSetId=c55e170e-3c75-49a5-8026-a961ff94c8e0&fileName=EDM_2023_Storm_Overflow_Annual_Return.zip',
    2024: 'https://environment.data.gov.uk/api/file/download?fileDataSetId=c55e170e-3c75-49a5-8026-a961ff94c8e0&fileName=EDM_2024_Storm_Overflow_Annual_Return.zip',}

RAW_DIR = os.path.join('data', 'raw') # builds the path (with correct slash directions) to data/raw/ where extracted Excel files will be saved.
os.makedirs(RAW_DIR, exist_ok=True) # creates the directory/folder (if it doesnt already exist)

def download_and_extract_edm(year, url, raw_dir): # defines a function which takes 3 inputs (year, url, and raw directory)
    
    # defines clean output filenames for the two Excel files we extract from each ZIP.
    main_filename = f'edm_main_{year}.xlsx' # edm_main_YYYY.xlsx = all companies combined
    summary_filename = f'edm_summary_{year}.xlsx' # edm_summary_YYYY.xlsx = national company-level totals (for national comparison later)
    # sets the file paths for each of the files extracted from each zip
    main_filepath = os.path.join(raw_dir, main_filename)
    summary_filepath = os.path.join(raw_dir, summary_filename)

    # skips the download if both files already exist locally - then lets the user know this has happened and the locations of each file
    if os.path.exists(main_filepath) and os.path.exists(summary_filepath):
        print(f'  {year}: already exists, skipping download.')
        return main_filepath, summary_filepath

    print(f'  {year}: downloading...', flush=True) # flush=True forces python to print the text immediately so that whats happening in real time can be seen
    response = requests.get(url, timeout=60) # sends an HTTP get request to the URL, saving the response. allows 1 minute wait for a response
    response.raise_for_status() # stops and gives a clear error if the server returned a failure code e.g. a 404 error


    zip_filepath = os.path.join(raw_dir, f'edm_{year}_temp.zip') # creates filepath for the temporary zip file the same as we've done before
    # saves the zip file to disk (temporarily) so zipfile can open it
    with open(zip_filepath, 'wb') as f:
        f.write(response.content) # writes the downloaded data to the disk (in binary mode)


    with zipfile.ZipFile(zip_filepath) as zf:
        all_files = zf.namelist() # returns all file paths inside the zip

        for file_path in all_files: # loops through each of the file paths within the zip
            # split('/') will split the string at every / (i.e. between levels within the filepath), meaning the final ([-1]) string after this spit is simply the filename
            # .lower() makes the matching case-insensitive.
            filename_only = file_path.split('/')[-1].lower()

            # identifies the main all-companies excel file and saves it.
            if 'all water and sewerage' in filename_only and filename_only.endswith('.xlsx'):
                with zf.open(file_path) as source, open(main_filepath, 'wb') as target:
                    target.write(source.read()) # copy contents from zip to disk (in binary mode)

            # identifies the summary excel file and saves it.
            elif 'summary data' in filename_only and filename_only.endswith('.xlsx'):
                with zf.open(file_path) as source, open(summary_filepath, 'wb') as target:
                    target.write(source.read()) # copy contents from zip to disk (in binary mode)
                    
    os.remove(zip_filepath) # deletes the temporary zip file now that everythings extracted (keeps our folder clean)
    
    # verifies both files were successfully extracted - raises errors if they weren't
    if not os.path.exists(main_filepath):
        raise FileNotFoundError(f'Could not find main all-companies Excel file in ZIP for {year}')
    if not os.path.exists(summary_filepath):
        raise FileNotFoundError(f'Could not find summary Excel file in ZIP for {year}')

    print('done.')
    time.sleep(0.5) # brief pause between server requests for politeness
    return main_filepath, summary_filepath

print('Downloading and extracting EDM files...')
# creates two empty dictionaries before the loop starts
edm_main_paths = {}
edm_summary_paths = {}

for year, url in EDM_URLS.items():
    main_path, summary_path = download_and_extract_edm(year, url, RAW_DIR) # calls the above function - saving the two file paths it returns
    # adds an entry to each dictionary for the current year
    edm_main_paths[year] = main_path
    edm_summary_paths[year] = summary_path

# prints a confirmation of what was downloaded - to visually verify everything worked
print('\nAll EDM files ready.')
print('\nMain files:')
for year, path in edm_main_paths.items(): 
    print(f'  {year}: {path}')
print('\nSummary files:')
for year, path in edm_summary_paths.items():
    print(f'  {year}: {path}')
# Out:
# ...
#   2021: already exists, skipping download.
#   2022: already exists, skipping download.
#   2023: already exists, skipping download.
#   2024: already exists, skipping download.
#
# All EDM files ready.
#
# Main files:
#   2021: data\raw\edm_main_2021.xlsx
#   2022: data\raw\edm_main_2022.xlsx
#   2023: data\raw\edm_main_2023.xlsx
#   2024: data\raw\edm_main_2024.xlsx
#
# Summary files:
#   2021: data\raw\edm_summary_2021.xlsx
#   2022: data\raw\edm_summary_2022.xlsx
#   2023: data\raw\edm_summary_2023.xlsx
#   2024: data\raw\edm_summary_2024.xlsx

# %% [markdown]
# ### 1a.1 Inspection Cells - EDM summary files (edm_summary_YYYY.xlsx)
# Scales 1, 2, and 3 - inspects sheet names and raw row structure of `edm_summary_YYYY.xlsx` before writing the section 6 parsing code.

# %%
for year, path in edm_summary_paths.items():
    xl = pd.ExcelFile(path) # opens the excel file without reading its contents yet
    print(f'{year} summary sheets: {xl.sheet_names}') # prints the list of sheet names for this year
# Out:
# 2021 summary sheets: ['2021 Summary Data']
# 2022 summary sheets: ['2022 Summary Data']
# 2023 summary sheets: ['2023 Summary Data']
# 2024 summary sheets: ['2024 Summary Data']

# %%
# previews the first 5 rows of the first sheet in each summary file (header=None so we see the raw rows including any title rows)
for year, path in edm_summary_paths.items():
    xl = pd.ExcelFile(path) # accesses the current excel file's structure (without loading any data)
    first_sheet = xl.sheet_names[0] # takes the first sheet name from the list
    print(f'\n{year} — sheet: "{first_sheet}" — first 5 rows:')
    preview = pd.read_excel(path, sheet_name=first_sheet, header=None, nrows=5) # reads only first 5 rows without assuming any header
    display(preview)
# Out:
# 2021 — sheet: "2021 Summary Data" — first 5 rows:
#     0                                                  1
# 0 NaN  EDM Storm Overflow Annual Return Summary Repor...
# 1 NaN                                                NaN
# 2 NaN                        Table 1: 2021 EDM Headlines
# 3 NaN               Table 2: 2021 EDM Summary Statistics
# 4 NaN                 Table 3: 2021 EDM Device Operation
# 2022 — sheet: "2022 Summary Data" — first 5 rows:
#     0                                                  1
# 0 NaN  EDM Storm Overflow Annual Return Summary Repor...
# 1 NaN                                                NaN
# 2 NaN                        Table 1: 2022 EDM Headlines
# 3 NaN               Table 2: 2022 EDM Summary Statistics
# 4 NaN                 Table 3: 2022 EDM Device Operation
# 2023 — sheet: "2023 Summary Data" — first 5 rows:
#     0                                                  1
# 0 NaN  EDM Storm Overflow Annual Return Summary Repor...
# ...

# %% [markdown]
# > finding: the first 5 rows reveal the sheet is a formatted report document containing multiple named tables stacked vertically rather than a simple flat table - at this point i opened the file directly in excel to visually assess the full structure>finding (from excel): the sheet contains named tables (table 1: headlines through table 6: annual return summary) separated by blank rows>actual data beginning at row 9>the cell below confirms this structure programmatically>ensures findings are reproducible without requiring other users to open the raw files manually

# %%
# reads further into each summary sheet to show where the data tables begin ect. (ie what we found in excel)
for year, path in edm_summary_paths.items():
    print(f'\n{year} — rows 0 to 60:') # prints a header line before each year's output so we can tell which output belongs to which year
    preview = pd.read_excel(path, sheet_name=f'{year} Summary Data', header=None, nrows=60) # reads 60 rows with no header assumption - shows exactly as they appear in the file including title rows and blank separator rows
    display(preview)  # displays this^ in the notebook output
# Out:
# 2021 — rows 0 to 60:
#     0                                                  1   \
# 0  NaN  EDM Storm Overflow Annual Return Summary Repor...
# 1  NaN                                                NaN
# 2  NaN                        Table 1: 2021 EDM Headlines
# 3  NaN               Table 2: 2021 EDM Summary Statistics
# 4  NaN                 Table 3: 2021 EDM Device Operation
# 5  NaN     Table 4: 2021 Storm Overflow Spill Performance
# 6  NaN         Table 5: 2021 Storm Overflow Spill Reasons
# 7  NaN  Table 6: 2021 EDM Storm Overflow Annual Return...
# 8  NaN                                                NaN
# 9  NaN                       Table 1:  2021 EDM Headlines
# 10 NaN  Total no. storm overflows listed in the annual...
# 11 NaN    Total no. storm overflows with EDM commissioned
# 12 NaN           % overflows listed with EDM commissioned
# 13 NaN         Total no. storm overflows with spill data
# 14 NaN  Average no. spills per storm overflow with spi...
# ...

# %% [markdown]
# > finding: the WFD waterbody catchment column is consistently named across years except 2024>2021–2023 uses 'WFD Waterbody Catchment Name (Cycle 2)' while 2024 uses 'WFD Waterbody Catchment Name (Cycle 3)'>name difference must be handled in code by selecting the correct column name per year
# > finding: values are clean and already grouped at river system level>confirms the column is usable directly as a grouping variable>minor issues to handle in code: capitalisation inconsistency>'Not part of a WFD catchment' and coastal and regional entries (e.g. 'Devon South', 'Cornwall North', 'Tor Bay', 'Scilly Isles') need excluding before proper river level analysis

# %% [markdown]
# ### 1a.2 Inspection Cells — EDM main files (edm_main_YYYY.xlsx)
# Scales 1, 2, and 3 - inspects sheet names and raw SWW sheet structure before writing the section 2 parsing code. Confirms sheet naming convention and header row position.

# %%
for year, path in edm_main_paths.items(): # cycles through each of the excel files
    xl = pd.ExcelFile(path) # accesses the current excel file's structure (without loading any data)
    print(f'\n{year} sheets:')
    for sheet in xl.sheet_names: # gives us a list of every sheet in the excel file
        print(f'  {sheet}')
# Out:
# 2021 sheets:
#   Anglian Water 2021
#   DCWW 2021
#   Northumbrian Water 2021
#   Severn Trent 2021
#   South West Water 2021
#   Southern Water 2021
#   Thames Water 2021
#   United Utilities 2021
#   Wessex Water 2021
#   Yorkshire Water 2021
#
# 2022 sheets:
#   Anglian Water 2022
#   DCWW 2022
#   Northumbrian Water 2022
#   Severn Trent 2022
#   South West Water 2022
#   Southern Water 2022
#   Thames Water 2022
#   United Utilities 2022
#   Wessex Water 2022
#   Yorkshire Water 2022
#
# 2023 sheets:
#   Anglian Water 2023
#   DCWW 2023
#   Northumbrian Water 2023
#   Severn Trent 2023
#   South West Water 2023
#   Southern Water 2023
#   Thames Water 2023
#   United Utilities 2023
#   Wessex Water 2023
#   Yorkshire Water 2023
#
# 2024 sheets:
#   Anglian Water 2024
#   DCWW 2024
#   Northumbrian Water 2024
#   Severn Trent 2024
#   South West Water 2024
#   Southern Water 2024
#   Thames Water 2024
#   United Utilities 2024
#   Wessex Water 2024
#   Yorkshire Water 2024

# %%
# previews the structure of SWW sheets - including any any header rows atop the file
for year, path in edm_main_paths.items():  # cycles through each of the excel files
    print(f'\n{year} — first 5 rows:')
    preview = pd.read_excel(path, sheet_name=f'South West Water {year}', header=None, nrows=5) # limits reading to the first 5 rows (i just want an understanding of the sheet's layout not to see the whole sheet)
    display(preview)
# Out:
# 2021 — first 5 rows:
#                                                   0   \
# 0  EDM STORM OVERFLOW REGULATORY ANNUAL RETURN - ...
# 1                                 Water Company Name
# 2                                   South West Water
# 3                                   South West Water
# 4                                   South West Water
#
#                                     1   \
# 0                                  NaN
# 1    Site Name\n(EA Consents Database)
# 2                   11 HIGH STREET CSO
# 3  DUNNING WALK COMBINED SEWER OVERFLO
# 4         121A ST. KATHERINES ROAD CSO
#
#                                           2   \
# 0                                        NaN
# 1  Site Name\n(WaSC operational)\n[optional]
# 2             11 HIGH STREET_CSO_HATHERLEIGH
# 3            XX DUNNINGS WALK_CSO_TEIGNMOUTH
# 4           121a ST KATHERINES RD_CSO_EXETER
#
#                                             3   \
# 0                                          NaN
# ...

# %% [markdown]
# > finding: sheet names follow pattern 'South West Water {year}' consistently across all years
# > finding: header row is consistently row 1 across all years (can use header=1 in all pd.read_excel calls)
# > finding: number of columns changes across years (select columns by name not position)

# %%
# provides the full list of column names for each year (to allow for manual identification of the useful columns and any naming differences across years)
for year, path in edm_main_paths.items():
    df_cols = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1, nrows=0) # nrows=0 ensures just the column headers are read
    print(f'\n{year} columns:')
    for i, col in enumerate(df_cols.columns): # enumerate gives both the column position number and the column name at once
        print(f'  {i}: {col}')
# Out:
# 2021 columns:
#   0: Water Company Name
#   1: Site Name
# (EA Consents Database)
#   2: Site Name
# (WaSC operational)
# [optional]
#   3: EA Permit Reference
# (EA Consents Database)
#   4: WaSC Supplementary Permit Ref.
# [optional]
#   5: Activity Reference on Permit
# (if >1 discharge on permit)
#   6: Storm Discharge Asset Type
#   7: Outlet Discharge NGR
# (EA Consents Database)
#   8: WFD Waterbody ID (Cycle 2)
# (discharge outlet)
#   9: WFD Waterbody Catchment Name (Cycle 2)
# (discharge outlet)
#   10: Receiving Water / Environment (common name)
# (EA Consents Database)
#   11: Shellfish Water
#  (only populate for storm overflow with a Shellfish Water EDM requirement)
#   12: Bathing Water
# (only populate for storm overflow with a Bathing Water EDM requirement)
#   13: Initial EDM Commission Date
#   14: Total Duration (hrs) all spills prior to processing through 12-24h count method
#   15: Counted spills using 12-24h count method
#   16: EDM Operation -
# ...

# %% [markdown]
# > *key columns confirmed across years:*
# > * site name: 'Site Name
# (EA Consents Database)'*
# > * receiving water: 'Receiving Water / Environment (common name)
# (EA Consents Database)'*
# > * spill count: 'Counted spills using 12-24h count method'
# > * spill duration: 'otal Duration (hrs) all spills prior to processing through 12-24h count method' in 2021-23 but changes to 'Total Duration (hh:mm:ss)...' in 24 (needs converting to decimal hours to match*
# > * grid reference: 'Outlet Discharge NGR\n(EA Consents Database)' (needed for any mapping)*

# %%
dart_matches = [] # creates empty list to fill later

# reads all four years then filters for rows containing 'dart' in the receiving water column (case-insensitive)
for year, path in edm_main_paths.items():
    df = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1)
    # .str.contains searches for a string within each string in the column
    # case=False makes the search case-insensitive
    # na=False means rows with missing values in this column return False rather than crashing
    mask = df['Receiving Water / Environment (common name)\n(EA Consents Database)'].str.contains('dart', case=False, na=False)
    dart_matches.append(df[mask]) # adds each match to the end of the dart_matches list created before

dart_matches_df = pd.concat(dart_matches, ignore_index=True) # temporarily puts all years together to see the matched river names
# prints the matches
print('Unique receiving water names matched by dart filter:')
matched_names = sorted(dart_matches_df['Receiving Water / Environment (common name)\n(EA Consents Database)'].dropna().unique())
for name in matched_names:
    print(f'  {name}')
print(f'\nTotal rows matched: {len(dart_matches_df)}')
# Out:
# Unique receiving water names matched by dart filter:
#   DART ESTUARY
#   DART ESTUARY (TIDAL)
#   DART ESTUARY(E)
#   DART RIVER ESTUARY(E)
#   LITTLE DART RIVER
#   LITTLE DART RIVER (S)
#   RIVER DART
#   RIVER DART (ESTUARINE)
#   RIVER DART ESTUARY
#   RIVER DART ESTUARY (E)
#   RIVER DART ESTUARY VIA SWS
#   RIVER DART ESTUARY(E)
#   RIVER DART VIA SWS (ESTUARINE)
#   Stream joining Lower Little Dart River
#   TRIB LITTLE DART (S)
#   TRIB LITTLE DART RIVER (S)
#   TRIB OF R.DART(E) VIA SW SEWER
#   TRIB OF THE DART ESTUARY
#   TRIB. OF LITTLE DART RIVER
#
# Total rows matched: 113

# %% [markdown]
# > finding: 'dart' filter also incorrectly captures little dart entries (a separate river unrelated to the river dart we are analysing) and estuarine entries (sites discharging into the tidal Dart Estuary rather than the freshwater river)
# > fix: add second filter excluding any row containing 'little dart' and 'estuar'

# %%
# removes little dart entries from matched results (the little dart is a separate river unrelated to the river dart we are analysing)

receiving_water_col = 'Receiving Water / Environment (common name)\n(EA Consents Database)'
is_not_little_dart = ~dart_matches_df[receiving_water_col].str.contains('little dart', case=False, na=False)
dart_all = dart_matches_df[is_not_little_dart].copy()

# prints the final matches after little dart removal
print(f'Rows after removing Little Dart entries: {len(dart_all)}')
print(f'\nConfirmed Dart catchment receiving water names:')
for name in sorted(dart_all[receiving_water_col].dropna().unique()):
    print(f'  {name}')
# Out:
# Rows after removing Little Dart entries: 88
#
# Confirmed Dart catchment receiving water names:
#   DART ESTUARY
#   DART ESTUARY (TIDAL)
#   DART ESTUARY(E)
#   DART RIVER ESTUARY(E)
#   RIVER DART
#   RIVER DART (ESTUARINE)
#   RIVER DART ESTUARY
#   RIVER DART ESTUARY (E)
#   RIVER DART ESTUARY VIA SWS
#   RIVER DART ESTUARY(E)
#   RIVER DART VIA SWS (ESTUARINE)
#   TRIB OF R.DART(E) VIA SW SEWER
#   TRIB OF THE DART ESTUARY

# %% [markdown]
# ### Section 1b - Fetch Met Office Regional Rainfall Files
# Scale 3 only - fetches Met Office UK regional rainfall series as plain text files, saving to `data/raw/`. Six sub-regions fetched, each mapped to one or more water companies in the national comparison. Monthly totals only (daily data unavailable).

# %%
# maps each regions lowercase filename key to its exact met office filename
# multiple companies may share a region (e.g. SWW and wessex both in England_SW_and_S_Wales)
MET_REGIONS = {
    'england_sw_and_s_wales': 'England_SW_and_S_Wales', # south west water, wessex water
    'england_se_and_central_s': 'England_SE_and_Central_S', # southern water, thames water
    'east_anglia': 'East_Anglia', # anglian water
    'midlands': 'Midlands', # severn trent water
    'england_nw_and_n_wales': 'England_NW_and_N_Wales', # united utilities, welsh water
    'england_e_and_ne': 'England_E_and_NE',} # yorkshire water, northumbrian water

MET_REGIONS_BASE_URL = 'https://www.metoffice.gov.uk/pub/data/weather/uk/climate/datasets/Rainfall/date/' # base URL - region filename appended in the loop below

for region_key, region_name in MET_REGIONS.items():
    filepath = os.path.join('data', 'raw', f'met_region_{region_key}.txt') # builds the save path for this regions file
    if not os.path.exists(filepath): # skips the download if the file already exists
        url = MET_REGIONS_BASE_URL + region_name + '.txt' # constructs the full URL for this region
        response = requests.get(url, timeout=60) # sends a get request to the URL, saving the response. allows 1 minute wait for a response
        response.raise_for_status() # stops and raises an error if the server returned a failure code
        with open(filepath, 'w') as f:
            f.write(response.text) # writes the raw text response to disk
        print(f'  saved: {filepath}') # prints the filepath it was saved to
    else:
        print(f'  already exists, skipping: {filepath}') # tells the user the save was skipped and gives filepath for where it was saved

print('\nAll Met Office regional rainfall files ready.')
# Out:
#   already exists, skipping: data\raw\met_region_england_sw_and_s_wales.txt
#   already exists, skipping: data\raw\met_region_england_se_and_central_s.txt
#   already exists, skipping: data\raw\met_region_east_anglia.txt
#   already exists, skipping: data\raw\met_region_midlands.txt
#   already exists, skipping: data\raw\met_region_england_nw_and_n_wales.txt
#   already exists, skipping: data\raw\met_region_england_e_and_ne.txt
#
# All Met Office regional rainfall files ready.

# %% [markdown]
# ### 1b Inspection Cells — Met Office regional rainfall
# Scale 3 only - confirms `skiprows=5` lands correctly and `ann` column is present and complete for 2021–2024 across all six regions.

# %%
# previews the SW file to confirm the correct skiprows value and column layout
sample_path = os.path.join('data', 'raw', 'met_region_england_sw_and_s_wales.txt')
df_met_preview = pd.read_csv(sample_path, skiprows=5, sep=r'\s+') # skiprows=5 - skips the metadata block at the top of each file
print(df_met_preview.tail(10)) # tail rather than head - confirms the most recent years are present
print(f'\nColumns: {df_met_preview.columns.tolist()}')
# Out:
#      year    jan    feb    mar    apr    may    jun    jul    aug    sep  \
# 181  2017   89.2   92.4  122.4   26.1   66.9  100.8  115.3   88.3  138.8
# 182  2018  153.9   65.2  168.2  103.0   49.3   13.7   52.7   91.0   89.0
# 183  2019   72.1   78.0  130.2   77.3   35.2  111.6   46.7  117.4  163.6
# 184  2020  128.6  240.9   91.0   44.1   12.1  135.4   77.0  153.9   59.4
# 185  2021  173.6  132.8   63.8   13.4  188.4   50.1   99.4   61.3   98.3
# 186  2022   60.4  140.9   63.3   36.9   57.1   69.1   29.3   35.3  111.1
# 187  2023  173.0   21.0  196.5   86.9   50.0   35.8  158.0  101.6  120.7
# 188  2024  125.9  227.8  159.7  115.0   94.7   35.5   94.1   73.1  160.5
# 189  2025  159.8   98.6   16.9   83.6   37.8   90.2   43.5   61.2  152.2
# 190  2026  215.3  173.7   67.5  588.7    NaN    NaN    NaN    NaN    NaN
#
#        oct    nov    dec    win    spr    sum    aut     ann
# 181   77.7  106.9  160.7  239.1  215.4  304.4  323.3  1185.4
# ...

# %% [markdown]
# > finding: skiprows=5 lands correctly - columns are year, monthly totals (jan-dec), seasonal totals (win/spr/sum/aut), and ann (annual total in mm)>ann column confirmed present and will be used as annual_rainfall_mm at scale 3>filter to year <=2024 required in phase 2 analysis

# %%
# loops all six regional files and prints ann (annual rainfall mm) for 2021-2024 - confirms data is present and parseable for all regions before section 6a uses them
for region_key in MET_REGIONS:
    filepath = os.path.join('data', 'raw', f'met_region_{region_key}.txt')
    df_region = pd.read_csv(filepath, skiprows=5, sep=r'\s+')  # same parse approach confirmed above
    df_region = df_region[df_region['year'].between(2021, 2024)][['year', 'ann']]  # filters to project years only
    print(f'\n{region_key}:')
    print(df_region.to_string(index=False))
# Out:
# england_sw_and_s_wales:
#  year    ann
#  2021 1275.7
#  2022 1130.9
#  2023 1534.7
#  2024 1487.1
#
# england_se_and_central_s:
#  year    ann
#  2021  807.1
#  2022  751.9
#  2023 1022.9
#  2024  998.3
#
# east_anglia:
#  year   ann
#  2021 634.9
#  2022 503.1
#  2023 775.7
#  2024 729.2
#
# midlands:
#  year   ann
#  2021 811.2
#  2022 721.5
#  2023 999.5
#  2024 998.2
#
# england_nw_and_n_wales:
#  year    ann
#  2021 1399.6
#  2022 1233.4
#  2023 1606.9
#  2024 1550.0
#
# england_e_and_ne:
#  year   ann
#  2021 800.2
#  2022 706.2
#  2023 960.7
#  2024 877.6

# %% [markdown]
# > finding: all six regional files parse correctly with skiprows=5 - ann values present and complete for all regions for 2021-2024 - no missing values - structure confirmed consistent across all regions as assumed above

# %% [markdown]
# ### Section 2a - Parse EDM Storm Overflow Data
# Scale 1 - reads the SWW sheet from each year's EDM file, applies the freshwater Dart filter (matches 'dart', excludes 'little dart' and 'estuar' — confirmed in inspection cells above) and converts 2024's `hh:mm:ss` duration format to decimal hours before saving to `data/processed/dart_overflows.csv`.

# %%
# confirmed column names (from inspection cells^)
COL_SITE = 'Site Name\n(EA Consents Database)'
COL_WATER = 'Receiving Water / Environment (common name)\n(EA Consents Database)'
COL_GRID_REF = 'Outlet Discharge NGR\n(EA Consents Database)'
COL_SPILLS = 'Counted spills using 12-24h count method'
COL_DUR_HRS = 'Total Duration (hrs) all spills prior to processing through 12-24h count method'  # 2021–2023
COL_DUR_HHMMSS = 'Total Duration (hh:mm:ss) all spills prior to processing through 12-24h count method'  # 2024 only

PROCESSED_DIR = os.path.join('data', 'processed')# builds the filepath
os.makedirs(PROCESSED_DIR, exist_ok=True) # makes the folder if it doesnt already exist

# converts the 2024 days hrs:mins:secs string to decimal hours (to match other years)
def hhmmss_to_hours(val):
    if pd.isna(val) or str(val).strip() == '':  # catches any missing or empty values before we try to split
        return np.nan  # returns NaN for blank or missing values
    
    val_str = str(val).strip()
    
    # deals with any strings put wackily by pandas to include days e.g. 1 days 13:45:00 **always put as 'days' even if only 1 day**
    days = 0
    if 'days' in val_str: # detects if string includes 'days'
        parts_days = val_str.split('days') # splits at days ie to give '1 ', ' 13:45:00'
        days = int(parts_days[0].strip()) # extracts the number of days
        val_str = parts_days[1].strip() # keeps just the hh:mm:ss remainder
    
    parts = val_str.split(':')  # splits the string at : (i.e. where the hrs mins and seconds are separated)
    hours = int(parts[0])
    minutes = int(parts[1])
    seconds = int(parts[2])
    
    return (days * 24) + hours + (minutes / 60) + (seconds / 3600)  # converts to decimal hours
    
yearly_frames = []  # creates empty list (to fill with a dataframe per year)

for year, path in edm_main_paths.items(): # loops through the main excel files

    df = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1)  # read the SWW sheet for this year

    # applies dart catchment filter verified in the raw inspection phase^
    is_dart = df[COL_WATER].str.contains('dart', case=False, na=False) # checks the recieving water column for 'dart' (case insensitive) and stores boolean value per row in is_dart variable
    is_little = df[COL_WATER].str.contains('little dart', case=False, na=False) # same as previous line but for 'litle dart' instead
    is_estuarine = df[COL_WATER].str.contains('estuar', case=False, na=False)  # ame as previous line but for 'estuar' instead - catches both 'estuary' and 'estuarine'
    df = df[is_dart & ~is_little & ~is_estuarine].copy() # keeps only the rows where is_dart is true and is_little and is_estuarine are not true (ie false)

    # calls the function ^ on 2024 to turn hrs, mins, seconds spill duration into decimal time value to match other years
    if year == 2024:
        df['spill_duration_hrs'] = df[COL_DUR_HHMMSS].apply(hhmmss_to_hours)
    else:
        df['spill_duration_hrs'] = pd.to_numeric(df[COL_DUR_HRS], errors='coerce') # converts excel values to clean numeric values (deals with blank or missing values by settin them as NaN)

    # renames the important columns into clean names
    df_clean = pd.DataFrame({
        'year' : year,
        'site_name' : df[COL_SITE].str.strip(),
        'receiving_water' : df[COL_WATER].str.strip(),
        'grid_ref' : df[COL_GRID_REF].str.strip(),
        'spill_count' : pd.to_numeric(df[COL_SPILLS], errors='coerce'),
        'spill_duration_hrs' : df['spill_duration_hrs'],})

    yearly_frames.append(df_clean) # adds each year's cleaned dataframe to the list created before the loop
    print(f'  {year}: {len(df_clean)} Dart overflow rows parsed') # prints confirmation line for each year as it completes

dart_overflows = pd.concat(yearly_frames, ignore_index=True) # combines the dataframes in the yearly_frames list vertically into 1 (resets the indexing to not restart for each year)
print(f'\nTotal rows across all years: {len(dart_overflows)}') # prints the rowcount of the combined dataframe (sanity check that everything seems to hve worked)
display(dart_overflows.head(10)) # shows the first 10 rows of the combined dataframe (confirm visually everything seems right)

dart_overflows.to_csv(os.path.join(PROCESSED_DIR, 'dart_overflows.csv'), index=False) # saves the parsed dart overflow data to data/processed/ before any further processing
print(f'Saved: {os.path.join(PROCESSED_DIR, "dart_overflows.csv")}') # prints the filepath of the saved csv as confirmation
# Out:
#   2021: 5 Dart overflow rows parsed
#   2022: 5 Dart overflow rows parsed
#   2023: 5 Dart overflow rows parsed
#   2024: 5 Dart overflow rows parsed
#
# Total rows across all years: 20
#    year             site_name                 receiving_water      grid_ref  \
# 0  2021    31 FORE STREET CSO  TRIB OF R.DART(E) VIA SW SEWER  SX 8057 6024
# 1  2021     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 2  2021     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 3  2021  OLD WOOLLEN MILL CSO                      RIVER DART  SX 7421 6715
# 4  2021        STAVERTON WWTW                      RIVER DART  SX 7963 6363
# 5  2022    31 FORE STREET CSO  TRIB OF R.DART(E) VIA SW SEWER  SX 8057 6024
# 6  2022     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 7  2022     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 8  2022  OLD WOOLLEN MILL CSO                      RIVER DART  SX 7421 6715
# ...

# %% [markdown]
# ### 2a Inspection Cells - WFD catchment names
# Scale 2 prep - confirms WFD catchment column names per year, extracts all unique catchment names and identifies 'Dart' vs 'DART' as distinct waterbodies (freshwater vs estuarine).

# %%
# confirms the exact name of the WFD waterbody catchment column in each years SWW sheet
for year, path in edm_main_paths.items(): # loops through each years main excel file
    df = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1, nrows=0) # reads only the header row - no data needed yet
    catchment_cols = [col for col in df.columns if 'catchment' in col.lower()] # finds any column whose name contains 'catchment' (case-insensitive)
    print(f'{year}: {catchment_cols}') # prints the matching column names for this year
# Out:
# 2021: ['WFD Waterbody Catchment Name (Cycle 2)\n(discharge outlet)']
# 2022: ['WFD Waterbody Catchment Name (Cycle 2)\n(discharge outlet)']
# 2023: ['WFD Waterbody Catchment Name (Cycle 2)\n(discharge outlet)']
# 2024: ['WFD Waterbody Catchment Name (Cycle 3)\n(discharge outlet)']

# %%
# extracts all unique wfd catchment names from the full SWW sheet across all years
all_catchment_names = [] # creates empty list to fill with catchment names from each year

for year, path in edm_main_paths.items(): # loops through each years main excel file
    df = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1) # reads the full sww sheet for this year
    catchment_col = get_wfd_catchment_col(year)  # gets the correct column name for this year (cycle 2 for 2021-2023, cycle 3 for 2024)
    names = df[catchment_col].dropna().unique().tolist() # extracts unique non null catchment names from this year
    all_catchment_names.extend(names) # adds this years names to the full list

unique_catchment_names = sorted(set(all_catchment_names)) # removes duplicates across years and sorts alphabetically
print(f'Total unique WFD catchment names: {len(unique_catchment_names)}\n')
for name in unique_catchment_names: # loops through each unique catchment name
    print(name) # prints each on a separate line for review
# Out:
# Total unique WFD catchment names: 264
#
# (S) RIVER SID AND (C) LYME BAY
# Abbey River
# Allen
# Aller Brook
# Aller Brook (Teign) - Lower
# Aller Brook (Teign) - Upper
# Alphin Brook
# Am Brook
# Amble
# Angarrack Stream
# Ashburn
# Avon (Devon Tidal) and Sth Hams - Slapton
# Avon (DevonTidal) and Sth Hams - Frogmore
# Avon - Lower
# Avon - Upper
# Aylesbeare Stream
# Ayleston Brook
# Benny Stream
# Bidwell Brook
# Blackaton Brook
# Blackbrook River
# Blackwater River
# Bolesbridge Water
# Bolingey Stream
# Bradiford Water
# Bradwell Stream
# Branscombe Stream
# Bray (Mole to Hole Water)
# Bray (Source to Hole Water)
# Bullow Brook
# CAMEL
# Caerhays Stream
# Calenick Stream
# Camel (De Lank to Stannon)
# Canworthy Water
# Carey
# Carrick Roads Outer
# Chelfham Stream
# Claw
# Combe Lake
# Coney Gut
# Coombe Valley Stream
# Cornwall North
# Corry Brook
# Cotehele Stream
# Crackington Stream
# Crinnis River
# Crooked Oak
# Culvery River
# DART
# Dalch
# Dart
# Dart (Exe)
# ...

# %% [markdown]
# > finding: the WFD waterbody catchment column is consistently named across years except 2024>2021–2023 uses 'WFD Waterbody Catchment Name (Cycle 2)' while 2024 uses 'WFD Waterbody Catchment Name (Cycle 3)'>name difference must be handled in code by selecting the correct column name per year
# > finding: values are clean and already grouped at river system level>confirms the column is usable directly as a grouping variable>all-caps labels (e.g. 'DART', 'CAMEL', 'FOWEY', 'TEIGN') sit alongside title-case equivalents (possibly to represent distinct tidal/estuarine waterbodies rather than being capitalisation errors) - this is investigated in the next cell>coastal/administrative entries (e.g. 'Not part of a WFD catchment', 'Devon South', 'Cornwall North', 'Tor Bay', 'Scilly Isles') may need excluding before river level analysis

# %%
# shows all raw catchment name values containing 'dart' across years before any normalisation is applied
for year, path in edm_main_paths.items():  # loops through each year's main EDM excel file
    df = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1)  # reads the SWW sheet for this year
    catchment_col = get_wfd_catchment_col(year)  # gets the correct column name for this year (cycle 2 for 2021-2023, cycle 3 for 2024)
    variants = df[catchment_col].dropna().unique()  # extracts all unique non-null catchment names for this year
    dart_variants = [v for v in variants if 'dart' in v.lower()]  # filters to only values containing 'dart' regardless of capitalisation
    for v in dart_variants:
        print(f'  {year}: "{v}"')  # prints each raw dart variant with its year so we can see exactly what inconsistencies exist before normalisation
# Out:
#   2021: "Dart (Exe)"
#   2021: "Lower Little River Dart"
#   2021: "Dart"
#   2021: "Upper Little Dart River"
#   2021: "Taw (River Yeo to Little Dart River)"
#   2021: "DART"
#   2022: "Dart (Exe)"
#   2022: "Lower Little River Dart"
#   2022: "Dart"
#   2022: "DART"
#   2022: "Upper Little Dart River"
#   2022: "Taw (River Yeo to Little Dart River)"
#   2023: "Dart (Exe)"
#   2023: "Lower Little River Dart"
#   2023: "Dart"
#   2023: "DART"
#   2023: "Upper Little Dart River"
#   2023: "Taw (River Yeo to Little Dart River)"
#   2024: "Dart"
#   2024: "Dart (Exe)"
#   2024: "Lower Little River Dart"
#   2024: "DART"
#   2024: "Upper Little Dart River"
#   2024: "Taw (River Yeo to Little Dart River)"

# %% [markdown]
# > finding: 'Dart' and 'DART' both appear in every year suggesting they are two distinct waterbodies not a capitalisation error>'Dart (Exe)', 'Lower Little River Dart', 'Upper Little Dart River', 'Taw (River Yeo to Little Dart River)' all refer to unrelated river systems>the next inspection cell confirms what sites fall under 'Dart' vs 'DART'

# %%
# finds which overflow sites and receiving waters come under each of 'Dart' and 'DART' - to confirm if they are distinct waterbodies or a capitalisation inconsistency
for label in ['Dart', 'DART']:
    print(f'\n=== WFD catchment label: "{label}" ===')
    for year, path in edm_main_paths.items():  # loops through each years main edm file
        df = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1)  # reads the SWW sheet for this year
        catchment_col = get_wfd_catchment_col(year)  # gets the correct column name for this year (cycle 2 for 2021-2023, cycle 3 for 2024)
        site_col = 'Site Name\n(EA Consents Database)'  # exact column name confirmed in 1a inspection cells^
        water_col = 'Receiving Water / Environment (common name)\n(EA Consents Database)'  # exact column name confirmed in 1a inspection cells^
        mask = df[catchment_col] == label  # exact string match - NOT title-cased, so 'Dart' and 'DART' are treated as distinct labels
        sites = df.loc[mask, [site_col, water_col]].drop_duplicates()  # extracts unique site/receiving water pairs for this label and year
        if not sites.empty:  # only prints if this label appears in this years data
            print(f'  {year}:')
            for _, row in sites.iterrows():  # loops through each unique site row
                print(f'    Site: {row[site_col]}  |  Receiving water: {row[water_col]}')
# Out:
# === WFD catchment label: "Dart" ===
#   2021:
#     Site: HOLNE WWTW  |  Receiving water: HOLY BROOK
#     Site: BUCKFASTLEIGH STW  |  Receiving water: RIVER DART
#     Site: OLD WOOLLEN MILL CSO  |  Receiving water: RIVER DART
#     Site: STAVERTON WWTW  |  Receiving water: RIVER DART
#     Site: SCORRITON STW  |  Receiving water: HOLY BROOK(S)
#   2022:
#     Site: HOLNE WWTW  |  Receiving water: HOLY BROOK
#     Site: BUCKFASTLEIGH STW  |  Receiving water: RIVER DART
#     Site: OLD WOOLLEN MILL CSO  |  Receiving water: RIVER DART
#     Site: SCORRITON STW  |  Receiving water: HOLY BROOK(S)
#     Site: STAVERTON WWTW  |  Receiving water: RIVER DART
#   2023:
#     Site: HOLNE WWTW  |  Receiving water: HOLY BROOK
#     Site: BUCKFASTLEIGH STW  |  Receiving water: RIVER DART
#     Site: OLD WOOLLEN MILL CSO  |  Receiving water: RIVER DART
#     Site: SCORRITON STW  |  Receiving water: HOLY BROOK(S)
#     Site: STAVERTON WWTW  |  Receiving water: RIVER DART
#   2024:
# ...

# %% [markdown]
# > finding: 'Dart' and 'DART' are distinct waterbodies>'Dart' covers 5 freshwater sites (Holne, Buckfastleigh, Staverton, Old Woollen Mill, Scorriton) discharging into the River Dart and Holy Brook - upper/mid catchment where paddling happens>'DART' covers 2 estuarine sites (Priory Slip, Yarrow Bank) discharging into the dart estuary (tidal, Dartmouth area)

# %% [markdown]
# ### Section 2b - Identify Top SWW Catchments
# Scale 2 - aggregates full SWW EDM data by WFD catchment label across 2021–2024, summing total spill counts and identifying the top 20 freshwater catchments by total spill count. Top 35 inspected manually to exclude all-caps estuarine WFD labels and non-river entries. `n_sites` recorded per catchment for cross-sectional normalisation in section 3c.

# %%
yearly_sww_frames = []  # empty list to fill with one dataframe per year

for year, path in edm_main_paths.items():  # loops through each years main EDM excel file
    df = pd.read_excel(path, sheet_name=f'South West Water {year}', header=1)  # reads the SWW sheet for this year

    catchment_col = get_wfd_catchment_col(year)  # gets the correct column name for this year (cycle 2 for 2021-2023, cycle 3 for 2024)

    spill_col = 'Counted spills using 12-24h count method'  # confirmed column name from 2a inspection cells^
    site_col  = 'Site Name\n(EA Consents Database)'  # confirmed column name from 1a inspection cells^

    df_year = pd.DataFrame({
        'year': year,  # adds the year as a column so we can track which year each row came from
        'catchment_name': df[catchment_col].str.strip(),  # strips leading/trailing whitespace only - casing preserved since all-caps labels are distinct waterbodies (confirmed in 2a inspection cells^)
        'site_name': df[site_col],  # carries site name through so distinct sites per catchment can be counted below
        'spill_count': pd.to_numeric(df[spill_col], errors='coerce'),})  # changes any non numeric values to NaN rather than raising an error

    yearly_sww_frames.append(df_year)  # adds the years cleaned dataframe to the list

sww_all = pd.concat(yearly_sww_frames, ignore_index=True)  # combines all years into one dataframe, resetting the index

# aggregates total spill counts per catchment across all four years - groups by catchment name, sums spill counts, excludes rows with no catchment assigned
total_spills = (sww_all.groupby('catchment_name', dropna=True)['spill_count'].sum()
    .reset_index().rename(columns={'spill_count': 'total_spills_2021_2024'}))

# counts distinct overflow sites per catchment across all years - passed through to section 3c to compute annual_spills_per_site
n_sites = (sww_all.dropna(subset=['catchment_name']).groupby('catchment_name')['site_name']
    .nunique().reset_index().rename(columns={'site_name': 'n_sites'}))

catchment_totals = total_spills.merge(n_sites, on='catchment_name', how='left') # merges total spills and site counts into one catchment level dataframe

# sorts by total spills highest to lowest and resets index so row numbers reflect rank order
catchment_totals = catchment_totals.sort_values('total_spills_2021_2024', ascending=False).reset_index(drop=True)

print(f'Total unique catchments before exclusion: {len(catchment_totals)}')
print('\nTop 35 catchments by total spill count (2021-2024):')
display(catchment_totals.head(35))  # displays top 35 for manual inspection - used to identify non-river entries for exclusion and to assess site-count variation across catchments
# Out:
# Total unique catchments before exclusion: 264
#
# Top 35 catchments by total spill count (2021-2024):
#                   catchment_name  total_spills_2021_2024  n_sites
# 0    Not part of a WFD catchment                 17088.0      499
# 1                  Teign (Lower)                  2706.0        8
# 2             Lower River Lynher                  2691.0        9
# 3              Lower River Tamar                  2267.0       10
# 4               Lower River Inny                  2201.0        5
# 5                           Dart                  2000.0        5
# 6                      Lower Axe                  1938.0        8
# 7               Spratford Stream                  1871.0        9
# 8               Lower River Tavy                  1835.0       11
# 9                     Lower Culm                  1802.0       12
# 10                    Wray Brook                  1725.0        9
# 11             Lower River Otter                  1709.0       17
# ...

# %% [markdown]
# > finding: 264 unique catchments before exclusion>only one exclusion required entry in the top 35 ('Not part of a WFD catchment')>all other top 35 entries are genuine river, non estuarine catchments
# > finding: site counts vary from 2 to 30 across the top 35 catchments>a range is too large to ignore>using total_spills as the ols dependent variable would penalise larger network catchments and flatter smaller network ones>annual_spills_per_site (computed in section 3c) is used instead

# %% [markdown]
# ### Section 3a - Fetch Daily Rainfall from EA Hydrology API
# Scale 1 - fetches daily rainfall from two EA gauges within the Dart catchment boundary: Holne Priddacott Farm (WISKI ID: 363710) and Austins Bridge (WISKI ID: 364176). Gauges identified manually via the EA Hydrology Data Explorer, cross-referenced against the Dart catchment boundary in the EA Catchment Data Explorer.
#
# API parameters confirmed from the OpenAPI spec at `environment.data.gov.uk/hydrology/doc/oas.json`. Station filtered via `station.wiskiID`. Correct measure identified by inspecting the raw JSON `measures` array on each station page - the daily series is identified by `periodName: daily` and notation string `rainfall-t-86400-mm-qualified` (rainfall / total / 86400s=24hrs / mm / quality-checked). Equivalent API parameters `observedProperty: rainfall` and `period: 86400` confirmed valid from the spec. Date bounds use `mineq-date`/`maxeq-date` (inclusive). `_limit: 500` set to return a full year in a single request without pagination. Notation confirmed consistent across both stations.
#
# Raw daily readings saved to `data/processed/dart_rainfall_daily.csv` before any aggregation.

# %%
# maps gauge names to WISKI IDs 
RAINFALL_GAUGES = {
    'Holne Priddacott Farm' : '363710', # northern catchment
    'Austins Bridge' : '364176',} # southern mid-catchment

YEARS = [2021, 2022, 2023, 2024] # creates a list of the years 
daily_path = os.path.join(PROCESSED_DIR, 'dart_rainfall_daily.csv') # builds filepath for the csv to be saved

def fetch_daily_rainfall(wiski_id, year):
    # queries the EA Hydrology API for daily rainfall readings for one gauge and one year
    # returns the list of daily reading dictionaries from the API response
    url = 'https://environment.data.gov.uk/hydrology/data/readings.json' # identified from the readings section of the API reference documentation
    params = {
    'station.wiskiID' : wiski_id,    # tells the API which station to retrieve data from using WISKI ID of the gauge station - confirmed valid parameter from OpenAPI spec
    'observedProperty' : 'rainfall',   # filters to rainfall readings only
    'period' : 86400, # filters to daily readings - 86400secs=24hrs
    'mineq-date' : f'{year}-01-01', # tells the API the start of the date range we want (boundary inclusive)
    'maxeq-date' : f'{year}-12-31', # tells the API the end of the date range we want (boundary inclusive)
    '_limit': 500,} # max rows returned - reasoning explained in mrkdown^ (ensures we get everything in one request)
    
    # sends actual API call including the params arguament with the dictionary of filter parameters we just defined^
    # requests constructs the full URL with parameters included from our arguament automatically
    # allows 30 seconds for the server to respond before raising an error (as we did in section 1^)
    response = requests.get(url, params=params, timeout=30) 
    response.raise_for_status() # raises an error if the server returned a failure code e.g. an error 404 (same logic as in section 1)
    data = response.json() # converts the raw json response into a python dictionary, such that the data is in an actually useable format

    items = data.get('items', []) # extracts the list of daily readings from the converted response (returns empty list if 'items' is missing)
    if not items: # checks if the 'items' list is empty - covers for scenario in which station reference or measure string is wrong, or station has no data for a given year
        print(f'    Warning: no data returned for station {wiski_id}, year {year} — check stationReference and measure string')
    return items # returns the list of daily readings we extracted
    
# skips the API fetch if the daily rainfall file already exists - preserves the saved data and avoids unnecessary repeated API calls
if os.path.exists(daily_path):
    print('dart_rainfall_daily.csv already exists, loading from disk.')
    dart_rainfall_daily = pd.read_csv(daily_path)
else: 
    print('Fetching daily rainfall from EA Hydrology API...')
    daily_records = []  # creates empty list for daily rows across both gauges and all years


    for gauge_name, wiski_id in RAINFALL_GAUGES.items(): # loops through each gauge
        for year in YEARS: # loops through each year for each gauge
            items = fetch_daily_rainfall(wiski_id, year) # calls the function above and stores the returned daily readings
            for item in items: # loops through each daily reading 
                daily_records.append({ # adds each daily reading to the list as a dictionary
                    'gauge_name' : gauge_name, # stores the readable name of the gauge ('holne priddacott farm' or 'austins bridge') as a column
                    'wiski_id' : wiski_id, # stores the WISKI ID of the station
                    'date' : item.get('date', ''), # extracts the date string from the daily reading dictionary - returns an empty string if key is missing
                    'year' : int(str(item.get('date', '0000'))[:4]), # extracts year from date string e.g. '2021-03-14' gives 2021
                    'rainfall_mm' : item.get('value', np.nan),}) # extracts the actual rainfall measurement in mm from the reading dictionary - returns NaN if missing
                
            print(f'  {gauge_name} | {year}: {len(items)} daily readings fetched') # prints progress - ie which name and year was just completed 
            time.sleep(0.5) # half second pause between requests (politeness)

    dart_rainfall_daily = pd.DataFrame(daily_records) # converts the list of dictionaries into a dataframe

    # saves the full daily dataset to data/processed/ before any aggregation
    dart_rainfall_daily.to_csv(daily_path, index=False) # saves the dataframe as a csv - prevents pandas from adding an index column
    print(f'\nSaved: {daily_path}') # prints save confirmation along with the filepath of the save location
print(f'Total daily rows loaded: {len(dart_rainfall_daily)}') # prints total number of rows saved for sanity check
display(dart_rainfall_daily.head(10)) # displays the first 10 rows of the csv - to visually confirm everything looks correct
# Out:
# dart_rainfall_daily.csv already exists, loading from disk.
# Total daily rows loaded: 2922
#               gauge_name  wiski_id        date  year  rainfall_mm
# 0  Holne Priddacott Farm    363710  2021-01-01  2021          0.2
# 1  Holne Priddacott Farm    363710  2021-01-02  2021          2.8
# 2  Holne Priddacott Farm    363710  2021-01-03  2021          0.0
# 3  Holne Priddacott Farm    363710  2021-01-04  2021          0.3
# 4  Holne Priddacott Farm    363710  2021-01-05  2021          0.0
# 5  Holne Priddacott Farm    363710  2021-01-06  2021          0.0
# 6  Holne Priddacott Farm    363710  2021-01-07  2021          0.7
# 7  Holne Priddacott Farm    363710  2021-01-08  2021          0.0
# 8  Holne Priddacott Farm    363710  2021-01-09  2021          0.0
# 9  Holne Priddacott Farm    363710  2021-01-10  2021          1.1

# %% [markdown]
# ### Section 3b - Compute Storm Days for Dart Catchment
# Scale 1 - calls `compute_storm_days()` on `dart_rainfall_daily.csv` to average daily readings across both gauges and count storm days per year at the 10, 15, and 20mm thresholds. Saves annual summary to `data/processed/dart_annual_storm_days.csv`.

# %%
dart_rainfall_daily = pd.read_csv(os.path.join(PROCESSED_DIR, 'dart_rainfall_daily.csv')) # loads the daily rainfall CSV saved in Section 3a

# calls the helper function we defined - compute_storm_days() (averages daily readings across both gauges per date, then counts storm days per year)
dart_annual_storm_days = compute_storm_days(dart_rainfall_daily)

print('Dart catchment storm days summary:')
display(dart_annual_storm_days)

# saves the annual summary to data/processed/
annual_path = os.path.join(PROCESSED_DIR, 'dart_annual_storm_days.csv')  # builds the file path
dart_annual_storm_days.to_csv(annual_path, index=False)  # saves without index column
print(f'\nSaved: {annual_path}') # shows the filepath for where it was saved
# Out:
# Dart catchment storm days summary:
#    year  storm_days_10  storm_days_15  storm_days_20
# 0  2021             62             43             25
# 1  2022             56             39             22
# 2  2023             82             54             36
# 3  2024             71             50             36
# Saved: data\processed\dart_annual_storm_days.csv

# %% [markdown]
# ### Section 3c - Fetch SWW Catchment Rainfall and Compute Storm Days
# Scale 2 - for each of the top 20 SWW catchments, finds the nearest EA rainfall gauge and fetches daily rainfall for 2021–2024. Calls `compute_storm_days()` per catchment and merges with `catchment_totals` to produce `sww_rivers.csv`.
#
# Catchment centroids derived by overlaying a bounding box onto the WFD boundary map from the EA Catchment Data Explorer, aligning edges to the northernmost, southernmost, easternmost, and westernmost points of the boundary. The midpoint was then read from Google Maps. Method applied identically across all 20 catchments.
#
# Nearest gauge selected using the EA Hydrology API stations endpoint, which accepts a lat/lon and search radius and returns stations sorted by distance. Only stations with `observedProperty=rainfall` are queried. A 10km radius should be tight enough to ensure local representativeness and large enough to absorb imprecision in the centroid method. Gauges assessed in distance order and the nearest with complete coverage across all four years selected. If the nearest gauge fails this check, the next nearest is tried.
#
# Known limitation: the nearest gauge may sit slightly outside the strict WFD catchment boundary for small or irregularly shaped catchments, and a single gauge may not fully represent the entire catchment rainfall. These are inherent constraints of the public gauge network.
#
# Daily rainfall per catchment saved to `data/raw/` before aggregation.

# %%
# maps each catchment name to its bounding box centroid lat/lon - method applied identically across all catchments
CATCHMENT_CENTROIDS = {
    'Teign (Lower)': (50.625132, -3.688755),
    'Lower River Lynher': (50.502805, -4.364948),
    'Lower River Tamar': (50.559614, -4.260444),
    'Lower River Inny': (50.584675, -4.368589),
    'Dart': (50.505137, -3.780237),
    'Lower Axe': (50.778322, -2.992206),
    'Spratford Stream': (50.917409, -3.366313),
    'Lower River Tavy': (50.531050, -4.126611),
    'Lower Culm': (50.850521, -3.389122),
    'Wray Brook': (50.645684, -3.742121),
    'Lower River Otter': (50.741082, -3.280301),
    'Torridge (Lew to Estuary)': (50.899389, -4.121009),
    'Harbourne River': (50.423462, -3.759486),
    'Allen': (50.577569, -4.744903),
    'Meavy': (50.502502, -4.034037),
    'Seaton': (50.443281, -4.417540),
    'Torridge (Combe Lake to Lew)': (50.845050, -4.172025),
    'Walkham': (50.554821, -4.073894),
    'Exe (Barle to Culm)': (50.890258, -3.532857),
    'Tale': (50.805837, -3.287496),}

HYDROLOGY_STATIONS_URL = 'https://environment.data.gov.uk/hydrology/id/stations.json' # EA hydrology API stations endpoint - used to find nearest gauge to a given lat/lon
MIN_READINGS_PER_YEAR = 365 # minimum daily readings required per year for a gauge to be considered complete

def find_nearest_rainfall_gauge(lat, lon, search_radius_km=10):
    # queries the EA hydrology API stations endpoint for rainfall gauges within search_radius_km of the given lat/lon
    # returns the wiski_id, label, rank, and gauge lat/lon of the nearest gauge with complete coverage, or (None, None, None, None, None) if none found within the radius
    params = {
        'lat': lat, # latitude of the catchment centroid
        'long': lon, # longitude of the catchment centroid
        'dist': search_radius_km, # search radius in km - set to 10km
        'observedProperty': 'rainfall',} # filters to rainfall gauges only 
        
    # sends the API call with the parameters dictionary - 'requests' constructs the full URL automatically (same logic as fetch_daily_rainfall^)
    response = requests.get(HYDROLOGY_STATIONS_URL, params=params, timeout=30)
    response.raise_for_status() # raises an error if the server returned a failure code e.g. a 404 (same logic as section 1^)
    stations = response.json().get('items', []) # extracts the list of matching stations from the response - returns empty list if 'items' is missing

    if not stations: # returns None if no gauges were found within the search radius
        return None, None, None, None, None

    # API returns stations sorted by distance - iterates through in order until one with complete coverage is found
    for rank, station in enumerate(stations, start=1): # enumerate gives each station its position in the list
        wiski_id = station.get('wiskiID', '') # extracts the WISKI ID of this station - used to fetch readings via fetch_daily_rainfall()
        label = station.get('label', '') # extracts the readable station name - used for logging and saved to the csv
        lat_gauge = station.get('lat', None) # extracts gauge latitude from API response - saved to csv for folium map
        lon_gauge = station.get('long', None) # extracts gauge longitude from API response - saved to csv for folium map
        if not wiski_id: # skips stations with no WISKI ID - cannot fetch readings without one
            continue
        # checks coverage for each year by fetching reading counts - rejects gauges with fewer than MIN_READINGS_PER_YEAR readings in any year
        coverage_ok = True # assumes complete coverage until a failing year is found
        for year in YEARS:
            items = fetch_daily_rainfall(wiski_id, year) # fetches readings for this year to check how many days are present
            time.sleep(1) # brief pause between year requests (politeness)
            if len(items) < MIN_READINGS_PER_YEAR: # flags this gauge as incomplete if any year falls below the threshold
                coverage_ok = False
                break # as theres no need to check remaining years once one fails
        if coverage_ok: # returns this gauge if all four years passed the coverage check
            return wiski_id, label, rank, lat_gauge, lon_gauge

    return None, None, None, None, None # returns None if no gauge within the radius had complete coverage across all four years


catchment_storm_days_list = [] # creates empty list to fill with one storm_days dataframe per catchment

for catchment_name, (lat, lon) in CATCHMENT_CENTROIDS.items(): # loops through each catchment and its centroid coordinates
    gauge_csv_path = os.path.join(RAW_DIR, f'sww_gauge_{catchment_name}.csv') # builds the filepath for this catchments per gauge daily rainfall csv

    if os.path.exists(gauge_csv_path): # skips the API fetch if the daily rainfall file already exists - preserves saved data and avoids unnecessary repeated API calls
        daily_df = pd.read_csv(gauge_csv_path)
        label = daily_df['gauge_name'].iloc[0] # recovers the gauge label from the saved file for logging
        print(f'  {catchment_name}: already exists, skipping fetch (gauge: {label})')

    else:
        wiski_id, label, rank, lat_gauge, lon_gauge = find_nearest_rainfall_gauge(lat, lon) # calls the function above to find the nearest gauge with complete coverage across all four years
        time.sleep(1) # brief pause after the stations query (politeness)

        if not wiski_id: # warns and skips this catchment if no gauge with complete coverage was found within 10km - it will be missing from sww_rivers.csv
            print(f'  {catchment_name}: WARNING - no gauge with complete coverage found within 10km, skipping')
            continue

        print(f'  {catchment_name}: selected gauge "{label}" (rank {rank}, wiski_id: {wiski_id}) — fetching...', flush=True) # flush=True forces python to print immediately so progress can be seen in real time - rank shows whether the nearest gauge or a fallback was used

        daily_records = [] # creates empty list for daily rows for this catchment across all years
        for year in YEARS: # loops through each year for this catchment
            items = fetch_daily_rainfall(wiski_id, year) # calls fetch_daily_rainfall() defined in section 3a - returns the list of daily reading dictionaries
            for item in items: # loops through each daily reading
                daily_records.append({ # adds each daily reading to the list as a dictionary - same structure as section 3a, with 'catchment' added to identify which catchment each row belongs to after concatenation
                    'gauge_name': label, # stores the readable name of the gauge as a column
                    'wiski_id': wiski_id, # stores the WISKI ID of the station
                    'catchment': catchment_name, # stores the catchment this gauge is representing
                    'gauge_lat': lat_gauge, # stores the gauge latitude - used by the folium map cell to draw centroid-to-gauge lines
                    'gauge_lon': lon_gauge, # stores the gauge longitude - used by the folium map cell to draw centroid-to-gauge lines
                    'date': item.get('date', ''), # extracts the date string from the daily reading dictionary - returns empty string if key is missing
                    'year': int(str(item.get('date', '0000'))[:4]), # extracts year from date string e.g. '2021-03-14' gives 2021
                    'rainfall_mm': item.get('value', np.nan),}) # extracts the actual rainfall measurement in mm - returns NaN if missing
            print(f'    {catchment_name} | {year}: {len(items)} daily readings fetched') # prints progress for each year as it completes
            time.sleep(1) # brief pause between year requests (politeness)

        daily_df = pd.DataFrame(daily_records) # converts the list of dictionaries into a dataframe
        daily_df.to_csv(gauge_csv_path, index=False) # saves the daily data to data/raw/ before any aggregation, prevents pandas from adding an index column
        print('  done.')

    # calls the helper function defined at the phase 1 header - averages daily readings across gauges per date then counts storm days per year
    storm_days = compute_storm_days(daily_df)
    storm_days['catchment_name'] = catchment_name # adds catchment name as a column so rows can be identified after all catchments are concatenated

    catchment_storm_days_list.append(storm_days) # adds this catchments storm days dataframe to the list

print(f'\nStorm days computed for {len(catchment_storm_days_list)} of {len(CATCHMENT_CENTROIDS)} catchments.')

sww_storm_days = pd.concat(catchment_storm_days_list, ignore_index=True) # combines all catchments into one dataframe, resetting the index

# removes the non-river entry, then extracts just the top 20 catchment names for filtering
catchment_totals_clean = catchment_totals[catchment_totals['catchment_name'] != 'Not part of a WFD catchment'].copy()
top_20_names = catchment_totals_clean.head(20)['catchment_name'].tolist()

# computes spill total per catchment per year — groupby [catchment_name, year] gives genuine year-level variation
annual_spills = (sww_all[sww_all['catchment_name'].isin(top_20_names)].dropna(subset=['catchment_name']).groupby(['catchment_name', 'year'], dropna=True)['spill_count'].sum().reset_index().rename(columns={'spill_count': 'annual_spill_total'}))

# n_sites is stable across years (confirmed in coverage check below) so computed once per catchment
n_sites_per_catchment = (sww_all[sww_all['catchment_name'].isin(top_20_names)].dropna(subset=['catchment_name']).groupby('catchment_name')['site_name'].nunique().reset_index().rename(columns={'site_name': 'n_sites'}))

annual_spills = annual_spills.merge(n_sites_per_catchment, on='catchment_name', how='left')

# annual_spills_per_site: spill total this year divided by site count - directly comparable across catchments
annual_spills['annual_spills_per_site'] = annual_spills['annual_spill_total'] / annual_spills['n_sites']

# merges with storm_days data on both catchment_name and year
sww_rivers = annual_spills.merge(sww_storm_days, on=['catchment_name', 'year'], how='left')
sww_rivers = sww_rivers.sort_values(['catchment_name', 'year']).reset_index(drop=True)

sww_rivers_path = os.path.join(PROCESSED_DIR, 'sww_rivers.csv')
sww_rivers.to_csv(sww_rivers_path, index=False)
print(f'\nSaved: {sww_rivers_path}')
print(f'Rows: {len(sww_rivers)} — expected 80 (20 catchments × 4 years)')
print(f'Columns: {list(sww_rivers.columns)}')
display(sww_rivers.head(20))
# Out:
#   Teign (Lower): already exists, skipping fetch (gauge: Bovey Tracey)
#   Lower River Lynher: already exists, skipping fetch (gauge: Stoke Climsland)
#   Lower River Tamar: already exists, skipping fetch (gauge: Stoke Climsland)
#   Lower River Inny: already exists, skipping fetch (gauge: Stoke Climsland)
#   Dart: already exists, skipping fetch (gauge: Austins Bridge)
#   Lower Axe: already exists, skipping fetch (gauge: Raymonds Hill)
#   Spratford Stream: already exists, skipping fetch (gauge: Hockworthy)
#   Lower River Tavy: already exists, skipping fetch (gauge: Dousland)
#   Lower Culm: already exists, skipping fetch (gauge: Killerton Beare Farm)
#   Wray Brook: already exists, skipping fetch (gauge: Mardon Down)
#   Lower River Otter: already exists, skipping fetch (gauge: Brookfield Farm)
#   Torridge (Lew to Estuary): already exists, skipping fetch (gauge: Allisland)
#   Harbourne River: already exists, skipping fetch (gauge: Harbertonford)
# ...

# %% [markdown]
# > finding: all 20 catchments found a gauge with complete coverage within 10km>17 used rank 1 (nearest), 3 required rank 2 fallback: lower river otter, harbourne river and seaton
# > finding: several geographically adjacent catchments share a gauge - lower river lynher, tamar and Inny share stoke climsland>lower river tavy and meavy share dousland>both torridge catchments share allisland>lower river otter and tale share brookfield farm>expected given gauge network density in these areas
# > finding: 2023 is the stormiest year across most catchments and 2022 the driest - consistent with dart catchment storm days in section 3b

# %% [markdown]
# ### Section 3c Inspection - Site Stability Check
# Scale 2 - confirms `n_sites` is stable across all four years for every catchment. Required before using `annual_spills_per_site` as the temporal dependent variable - if site counts changed over time, year-on-year changes could reflect coverage expansion rather than genuine spill behaviour.

# %%
# loads sww_rivers.csv and checks whether n_sites is the same across all four years for each catchment
sww_rivers_check = pd.read_csv(os.path.join(PROCESSED_DIR, 'sww_rivers.csv'))

# pivots so each row is a catchment and each column is a year - makes it easy to compare n_sites across years
n_sites_pivot = sww_rivers_check.pivot_table(index='catchment_name', columns='year', values='n_sites', aggfunc='first')
n_sites_pivot['range'] = n_sites_pivot.max(axis=1) - n_sites_pivot.min(axis=1) # max minus min across years - zero means perfectly stable
n_sites_pivot = n_sites_pivot.sort_values('range', ascending=False) # sorts highest variation first so any problems are immediately visible

print('n_sites by catchment and year (sorted by range):')
print(n_sites_pivot.to_string())
# Out:
# n_sites by catchment and year (sorted by range):
# year                          2021  2022  2023  2024  range
# catchment_name
# Allen                            3     3     3     3      0
# Dart                             5     5     5     5      0
# Walkham                          5     5     5     5      0
# Torridge (Lew to Estuary)        9     9     9     9      0
# Torridge (Combe Lake to Lew)     4     4     4     4      0
# Teign (Lower)                    8     8     8     8      0
# Tale                             4     4     4     4      0
# Spratford Stream                 9     9     9     9      0
# Seaton                          10    10    10    10      0
# Meavy                            6     6     6     6      0
# Lower River Tavy                11    11    11    11      0
# Lower River Tamar               10    10    10    10      0
# Lower River Otter               17    17    17    17      0
# Lower River Lynher               9     9     9     9      0
# ...

# %% [markdown]
# > finding: all 20 catchments have stable n_sites across 2021-2024 (range=0 for every catchment)>year on year changes in annual_spills_per_site reflect genuine changes in spill behaviour not coverage expansion

# %% [markdown]
# ### Section 3d - Merge Dart Overflows with Storm Days
# Scale 1 - merges `dart_overflows.csv` with `dart_annual_storm_days.csv` on `year` (many-to-one). Overwrites `dart_overflows.csv` in `data/processed/` with the improved version.

# %%
# loads the two processed CSVs produced in sections 2 and 3b
dart_overflows = pd.read_csv(os.path.join(PROCESSED_DIR, 'dart_overflows.csv'))
dart_annual_storm_days = pd.read_csv(os.path.join(PROCESSED_DIR, 'dart_annual_storm_days.csv'))

# merges on year - many overflow rows (22 per year) joining to one storm_days row per year
# validate='m:1' checks that dart_annual_storm_days really is one row per year - raises an error if not
dart_overflows = pd.merge(dart_overflows, dart_annual_storm_days, on='year', how='left', validate='m:1')

# confirms the merge worked - should still be 88 rows, now with storm_days columns
print(f'Rows after merge: {len(dart_overflows)}')
print(f'Columns: {list(dart_overflows.columns)}')
display(dart_overflows.head(10))  # shows first 10 rows of the dataframe

dart_overflows.to_csv(os.path.join(PROCESSED_DIR, 'dart_overflows.csv'), index=False)  # overwrites dart_overflows.csv with the merged version
print(f'\nSaved: {os.path.join(PROCESSED_DIR, "dart_overflows.csv")}')
# Out:
# Rows after merge: 20
# Columns: ['year', 'site_name', 'receiving_water', 'grid_ref', 'spill_count', 'spill_duration_hrs', 'storm_days_10', 'storm_days_15', 'storm_days_20']
#    year             site_name                 receiving_water      grid_ref  \
# 0  2021    31 FORE STREET CSO  TRIB OF R.DART(E) VIA SW SEWER  SX 8057 6024
# 1  2021     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 2  2021     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 3  2021  OLD WOOLLEN MILL CSO                      RIVER DART  SX 7421 6715
# 4  2021        STAVERTON WWTW                      RIVER DART  SX 7963 6363
# 5  2022    31 FORE STREET CSO  TRIB OF R.DART(E) VIA SW SEWER  SX 8057 6024
# 6  2022     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 7  2022     BUCKFASTLEIGH STW                      RIVER DART  SX 7513 6581
# 8  2022  OLD WOOLLEN MILL CSO                      RIVER DART  SX 7421 6715
# ...

# %% [markdown]
# ### Section 3e - National Data Collection and national_summary.csv
# Scale 3 - parses the EDM summary Excel files to extract total spill counts and monitored site counts per company per year. Row labels located by partial string matching rather than hardcoded positions - label wording varies slightly across years (confirmed in 1a.1 inspection cells). Merges with Met Office regional rainfall via `COMPANY_REGION_MAP`. Welsh Water excluded as explained in writeup.
# Saves to `data/processed/national_summary.csv`.

# %%
# maps each company name (exactly as it appears in the summary file header row, confirmed in 1a.1 inspection cells) to its met office region key
COMPANY_REGION_MAP = {
    'Anglian Water (AWS)': 'east_anglia',
    'Northumbrian Water (NW)': 'england_e_and_ne',
    'Severn Trent Water (SvT)': 'midlands',
    'South West Water (SWW)': 'england_sw_and_s_wales',
    'Southern Water (SW)': 'england_se_and_central_s',
    'Thames Water (TW)': 'england_se_and_central_s',
    'United Utilities (UU)': 'england_nw_and_n_wales',
    'Wessex Water (WSSX)': 'england_sw_and_s_wales',
    'Yorkshire Water (YWS)': 'england_e_and_ne',}

# builds a rainfall lookup dictionary: {(region_key, year): ann_mm} from the six downloaded regional files
rainfall_lookup = {}
for region_key in MET_REGIONS:
    filepath = os.path.join('data', 'raw', f'met_region_{region_key}.txt')
    df_region = pd.read_csv(filepath, skiprows=5, sep=r'\s+')  # skiprows=5 confirmed correct in 1b inspection cells
    df_region = df_region[df_region['year'].between(2021, 2024)]  # filters to project years only - later years present in files but not needed
    for _, row in df_region.iterrows():
        rainfall_lookup[(region_key, int(row['year']))] = row['ann']  # stores annual rainfall mm keyed by (region, year) for fast lookup below

national_records = []  # empty list - one dictionary per company year appended inside the loop below

for year, path in edm_summary_paths.items():
    sheet_name = f'{year} Summary Data'
    raw = pd.read_excel(path, sheet_name=sheet_name, header=None)  # reads the full sheet with no header assumption - because the sheet contains multiple stacked tables rather than a simple flat table

    col1 = raw.iloc[:, 1].astype(str)  # column 1 holds all row labels across all tables in the sheet

    # locates the table 2 data header row - col 1 contains 'table 2' twice: once in the index list at the top of the sheet and once as the actual data header further down - index [1] selects the second match which is the actual data header row (both matches confirmed in 1a.1 inspection cells)
    table2_matches = col1[col1.str.contains('Table 2', na=False)].index
    header_row = raw.iloc[table2_matches[1]]  # the data header row - company names sit across columns 2 onwards of this row
    companies = [c for c in header_row.iloc[2:].tolist() if isinstance(c, str) and c in COMPANY_REGION_MAP]  # extracts company names present in our mapping - drops the totals and average columns at the end

    # locates the total spills row using partial string match - exact label wording varies by year (confirmed in 1a.1 inspection cells
    spills_idx = col1[col1.str.contains('spill events', na=False)].index
    spills_row = raw.iloc[spills_idx[0]]  # first match is always the total spills row

    # locates the monitored sites row using partial string match - exact label wording also varies by year (confirmed in 1a.1 inspection cells)
    sites_idx = col1[col1.str.contains('storm overflows with spill data', na=False)].index
    sites_row = raw.iloc[sites_idx[0]]  # first match is always the monitored sites row

    for company in companies:
        col_idx = header_row[header_row == company].index[0]  # finds the column index of this company in the header row - used to extract its values from the spills and sites rows below
        total_spills = pd.to_numeric(spills_row[col_idx], errors='coerce')   # extracts this companys total spill count - turns any non-numeric cells to NaN
        monitored_sites = pd.to_numeric(sites_row[col_idx], errors='coerce')    # extracts this companys monitored overflow count - turns any non-numeric cells to NaN
        region_key = COMPANY_REGION_MAP[company]  # looks up which met office region this company maps to
        annual_rainfall = rainfall_lookup.get((region_key, year), np.nan)  # retrieves the ann rainfall figure for this region year
        national_records.append({  # builds one dictionary per company year and adds it to the records list
            'year': year,
            'company': company,
            'region_key': region_key,
            'total_spills': total_spills,
            'monitored_sites': monitored_sites,
            'annual_rainfall_mm': annual_rainfall,})

national_df = pd.DataFrame(national_records)  # converts the list of dictionaries into a single dataframe - one row per company year
national_df['spills_per_monitored_site'] = national_df['total_spills'] / national_df['monitored_sites']  # divides total spills by monitored sites to give a fair per site rate comparable across companies

PROCESSED_DIR = os.path.join('data', 'processed')
national_df.to_csv(os.path.join(PROCESSED_DIR, 'national_summary.csv'), index=False)  # saves to data/processed/ 

print('national_summary.csv saved.')
print(f'rows: {len(national_df)}, columns: {list(national_df.columns)}')  # confirms row count and column names
print(f'\nspills_per_monitored_site range: {national_df["spills_per_monitored_site"].min():.1f} – {national_df["spills_per_monitored_site"].max():.1f}')
display(national_df.sort_values(['year', 'company']).head(10))  # previews first 10 rows sorted by year and company to visually confirm structure and values look correct
# Out:
# national_summary.csv saved.
# rows: 36, columns: ['year', 'company', 'region_key', 'total_spills', 'monitored_sites', 'annual_rainfall_mm', 'spills_per_monitored_site']
#
# spills_per_monitored_site range: 15.3 – 45.4
#    year                   company                region_key  total_spills  \
# 0  2021       Anglian Water (AWS)               east_anglia      21351.00
# 1  2021   Northumbrian Water (NW)          england_e_and_ne      36483.00
# 2  2021  Severn Trent Water (SvT)                  midlands      59684.00
# 3  2021    South West Water (SWW)    england_sw_and_s_wales      42484.00
# 4  2021       Southern Water (SW)  england_se_and_central_s      19077.41
# 5  2021         Thames Water (TW)  england_se_and_central_s      14713.00
# 6  2021     United Utilities (UU)    england_nw_and_n_wales      81588.00
# 7  2021       Wessex Water (WSSX)    england_sw_and_s_wales      23524.00
# 8  2021     Yorkshire Water (YWS)          england_e_and_ne      70062.00
# ...

# %% [markdown]
# > finding: national_summary.csv built successfully - 36 rows (9 companies x 4 years), all columns populated with no missing values>spills_per_monitored_site ranges from 15.3 to 45.4 across all company years>anglian waters monitored_sites growing from 834 in 2021 - coverage expansion to be examined properly in section 6b

# %% [markdown]
# ## Phase 2 - Analysis and Visualisation
#
# > this phase loads only from saved CSVs in data/processed/ - no API calls or fetching
# > contains all OLS modelling, residuals computation, and visualisations
# > section 4a-4c: scale 1 - Dart freshwater OLS and sensitivity check
# > section 4d-4e: scale 1 validation - per catchment residuals and slope table across full SWW panel
# > section 5: scale 2 - SWW catchment analysis: OLS ranking and trend analysis
# > section 6: scale 3 - national company analysis: OLS ranking and trend analysis

# %% [markdown]
# ### Section 4 - Interactive Map: SWW Catchment Centroids, Selected Gauges, and Scale 1 Dart Gauges
# Orientation map - plots the 20 catchment centroids connected by lines to their selected EA rainfall gauges. Dart catchment in blue, all others in orange. Both scale 1 Dart gauges marked in blue: Austins Bridge (also the scale 2 Dart gauge) and Holne Priddons Farm (scale 1 only). Holne Priddons Farm coordinates hardcoded from the EA Hydrology API station JSON. Saves to `outputs/folium_map.html`.

# %%
gauge_coords = {} # builds a lookup of gauge coordinates from the per catchment CSVs produced in section 3
for catchment_name in CATCHMENT_CENTROIDS: # loops through each catchment
    csv_path = os.path.join(RAW_DIR, f'sww_gauge_{catchment_name}.csv') # builds the filepath for this catchments gauge CSV
    if os.path.exists(csv_path): # skips if the file doesnt exist
        row = pd.read_csv(csv_path).iloc[0] # reads the first row - gauge metadata is identical across all rows in the file
        gauge_coords[catchment_name] = (float(row['gauge_lat']), float(row['gauge_lon']), str(row['gauge_name'])) # stores coords and name

m = folium.Map(location=[50.60, -3.85], zoom_start=9, tiles='CartoDB positron') # initialises the folium map centred on devon

for catchment_name, (c_lat, c_lon) in CATCHMENT_CENTROIDS.items(): # loops through each catchment centroid
    is_dart = catchment_name == 'Dart' # flags the dart catchment for distinct colouring
    colour = COLOUR_DART if is_dart else COLOUR_SWW # dart in blue, all others in orange - matches the colour scheme used throughout the notebook
    pin_colour = 'blue' if is_dart else 'orange' # folium.Icon only accepts named colours - blue good enough for COLOUR_DART orange good enough for COLOUR_SWW

    folium.Marker( # plots the catchment centroid as a small filled circle using DivIcon
        location=[c_lat, c_lon], tooltip=f'<b>{catchment_name}</b><br>catchment centroid',
        icon=folium.DivIcon(
            html=f'<div style="width:14px;height:14px;border-radius:50%;background:{colour};border:1.5px solid #fff;box-shadow:0 0 2px rgba(0,0,0,0.4);"></div>',
            icon_size=(14, 14),icon_anchor=(7, 7)),).add_to(m)

    if catchment_name in gauge_coords: # only plots the gauge and connecting line if coordinates were successfully loaded
        g_lat, g_lon, g_name = gauge_coords[catchment_name] # unpacks the gauge coordinates and name

        folium.PolyLine( # draws a line connecting the catchment centroid to its selected gauge - makes the centroid to gauge offset visually explicit
            locations=[[c_lat, c_lon], [g_lat, g_lon]],
            color=colour, # same colour as its catchment centroid
            weight=1.5, opacity=0.5, tooltip=f'{catchment_name} → {g_name}',).add_to(m)

        folium.Marker(location=[g_lat, g_lon], tooltip=f'<b>gauge:</b> {g_name}<br>({catchment_name})', icon=folium.Icon(color=pin_colour, icon='tint', prefix='fa'),).add_to(m) # plots the selected gauge as a folium pin marker

folium.Marker( # plots holne priddons farm separately - used at scale 1 only (averaged with austins bridge)
    location=[50.516929, -3.841878], # from EA hydrology api station json manually identified gauge not covered by section 3c
    tooltip='<b>gauge:</b> Holne Priddons Farm<br>(Dart)', icon=folium.Icon(color='blue', icon='tint', prefix='fa'),).add_to(m)

map_path = os.path.join(OUTPUTS_DIR, 'folium_map.html') # builds the filepath for the saved map
m.save(map_path)
print(f'Map saved: {map_path}')
m # displays the interactive map inline in the notebook
# Out:
# Map saved: outputs\folium_map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Section 4a - Scale 1 OLS: Dart Freshwater Overflow Residuals
# scale 1 - loads `dart_overflows.csv`, aggregates to annual totals, fits OLS regressing total annual freshwater spill count on `storm_days_10`. Stores fitted values and residuals in `dart_annual`. With only 4 data points the model is indicative - see narrative for interpretation.

# %%
dart_overflows = pd.read_csv(os.path.join(PROCESSED_DIR, 'dart_overflows.csv')) # loads dart_overflows.csv
print(f'Loaded dart_overflows.csv: {len(dart_overflows)} rows, {dart_overflows["year"].nunique()} years, {dart_overflows["site_name"].nunique()} sites')

dart_annual = (dart_overflows.groupby('year', as_index=False)['spill_count'].sum().rename(columns={'spill_count': 'total_spill_count'})) # sums spill_count across all freshwater sites to give one total per year

storm_days_by_year = (dart_overflows.groupby('year', as_index=False)[['storm_days_10', 'storm_days_15', 'storm_days_20']].first()) # as storm_days are identical for all sites within a year for the same catchment (dart in this case), we take the first row per year

dart_annual = pd.merge(dart_annual, storm_days_by_year, on='year', how='left', validate='1:1') # merges storm_days onto the annual spill totals matching on year - validate='1:1' confirms each year appears exactly once on both sides
print('\nAnnual freshwater spill count and storm days:')
print(dart_annual.to_string(index=False))

dart_ols_10 = smf.ols('total_spill_count ~ storm_days_10', data=dart_annual).fit() # fits OLS regressing total annual spill count on storm_days_10
print(f'\nScale 1 OLS summary (storm_days_10):')
print(dart_ols_10.summary())

dart_annual['fitted_10'] = dart_ols_10.fittedvalues # stores the models predicted spill count for each year
dart_annual['residual_10'] = dart_ols_10.resid # stores the residual - positive means more spills than storm pressure alone predicts

print('\dart_annual with residuals:')
print(dart_annual[['year', 'storm_days_10', 'total_spill_count', 'fitted_10', 'residual_10']].to_string(index=False))
# Out:
# Loaded dart_overflows.csv: 20 rows, 4 years, 4 sites
#
# Annual freshwater spill count and storm days:
#  year  total_spill_count  storm_days_10  storm_days_15  storm_days_20
#  2021              278.0             62             43             25
#  2022              237.0             56             39             22
#  2023              360.0             82             54             36
#  2024              355.0             71             50             36
#
# Scale 1 OLS summary (storm_days_10):
#                             OLS Regression Results
# ...
# Dep. Variable:      total_spill_count   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     12.81
# Date:                Mon, 04 May 2026   Prob (F-statistic):             0.0700
# Time:                        13:37:28   Log-Likelihood:                -17.483
# ...

# %% [markdown]
# > finding: storm days explain approximately 80% of the variance in annual freshwater spill count (adjusted R-squared = 0.797)>each additional storm day is associated with approximately 5 extra spills (coefficient = 4.94), though the 95% confidence interval is wide (approximately -1.0 to +10.9) reflecting the small sample
# > finding: p-value of 0.070 - the relationship is strongly suggestive but does not reach statistical significance at the 5% level>with only 4 observations this is unsurprising and does not invalidate the analysis>scale 2 carries the analytical weight (its sample size is larger)
# > finding: 2024 stands out - it had fewer storm days than 2023 (71 vs 82) yet produced a similar spill count (355 vs 360)>the model predicts 2024 should have seen notably fewer spills than 2023 given the lower storm pressure, but it didn't>the +31.4 residual for 2024 is the largest in absolute terms and is the central scale 1 finding

# %% [markdown]
# ### Section 4b - Scale 1 OLS Residuals Chart
# scale 1 - plots the OLS fit line against actual annual spill counts with vertical residual lines per year. Saved to `outputs/scale1_dart_ols_residuals.png`. Interactive Plotly version follows in the next cell.

# %%
fig, ax = plt.subplots(figsize=(8, 5))# creates the figure and a single axes object to plot on - figsize sets the output dimensions

x_range = np.linspace(dart_annual['storm_days_10'].min() - 5, dart_annual['storm_days_10'].max() + 5, 200) # generates 200 evenly spaced x values slightly beyond the observed range so the fit line doesnt end too abruptly
y_fit = dart_ols_10.params['Intercept'] + dart_ols_10.params['storm_days_10'] * x_range # finds y = a + bx at each point in x_range using the fitted intercept and slope coefficients - gives the predicted spill count at any storm_days_10 value
ax.plot(x_range, y_fit, color=COLOUR_NATIONAL, linewidth=1.5, linestyle='--', label='OLS fit', zorder=2) # draws the fit line in grey - zorder=2 places it behind the data points and residual lines (which are drawn at higher zorders)

for _, row in dart_annual.iterrows(): # iterates through dart_annual row by row - one iteration per year - giving access to each years storm days, fitted value, actual count and residual as a named series
    above = row['residual_10'] > 0 # true if actual spill count is above the models prediction for this year - determines colour and sign prefix below
    colour = COLOUR_DART if above else '#a8c4e0' # dark blue if above predicted, light blue if below - makes the direction of each residual visible without needing to read the label
    residual_sign = '+' if above else '' # adds a + before positive residuals so labels read (+31.4) and (-17.9) rather than (31.4) and (-17.9)

    # plots a vertical line between the fitted value and the actual value for this year - the length of this line is the residual, its direction shows whether actual was above or below the models ptrediction
    ax.plot([row['storm_days_10'], row['storm_days_10']], [row['fitted_10'], row['total_spill_count']],
            color=colour, linewidth=1.2, zorder=3)

    ax.scatter(row['storm_days_10'], row['total_spill_count'],
               color=colour, s=90, zorder=5, edgecolors='white', linewidths=0.5) # plots the actual observed spill count - zorder=5 ensures it draws on top of the residual line

    ax.annotate(f"{int(row['year'])}\n({residual_sign}{row['residual_10']:.1f})",
                xy=(row['storm_days_10'], row['total_spill_count']),
                xytext=(8, 0), textcoords='offset points',
                fontsize=9, color='#333333', va='center') # places a text label at each point showing the year and residual value - xytext=(8,0) offsets it to the right so it doesnt overlap the marker

# defines the labels and styling
ax.set_xlabel('storm days (days with ≥10 mm catchment-averaged rainfall)', fontsize=11)
ax.set_ylabel('total annual freshwater spill count', fontsize=11)
ax.set_title('Dart freshwater spill count vs storm-day pressure, 2021–2024\nresiduals show spills above (+) or below (−) what weather alone predicts', fontsize=11)
ax.legend(fontsize=9)
sns.despine(ax=ax)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale1_dart_ols_residuals.png'), dpi=150, bbox_inches='tight')
plt.show()
print('Saved: outputs/scale1_dart_ols_residuals.png') # prints save location and filename
# Out:
# Saved: outputs/scale1_dart_ols_residuals.png

# %% [markdown]
# ### Section 4c - Sensitivity Check: Storm Day Threshold
# scale 1 - re-runs the OLS at 15mm and 20mm thresholds. Tests whether the 2024 residual anomaly is robust to the choice of 10mm. The meaningful test is residual signs and rankings across thresholds, not R-squared values - see narrative for interpretation.

# %%
# fits OLS at 15mm and 20mm thresholds - mirrors the structure of dart_ols_10 in section 4a
dart_ols_15 = smf.ols('total_spill_count ~ storm_days_15', data=dart_annual).fit() # same model as dart_ols_10 but with storm_days_15 as regressor
dart_ols_20 = smf.ols('total_spill_count ~ storm_days_20', data=dart_annual).fit() # same model again with storm_days_20 as regressor

# stores fitted values and residuals for each threshold - positive residual means more spills than the model predicted
dart_annual['fitted_15'] = dart_ols_15.fittedvalues
dart_annual['residual_15'] = dart_ols_15.resid
dart_annual['fitted_20'] = dart_ols_20.fittedvalues
dart_annual['residual_20'] = dart_ols_20.resid

# prints the model summary statistics across all three thresholds side by side
print('Scale 1 OLS sensitivity check - threshold comparison:')
print(f"{'metric':<28} {'10mm':>8} {'15mm':>8} {'20mm':>8}")
print('-' * 56)
print(f"{'R-squared':<28} {dart_ols_10.rsquared:>8.3f} {dart_ols_15.rsquared:>8.3f} {dart_ols_20.rsquared:>8.3f}")
print(f"{'adj. R-squared':<28} {dart_ols_10.rsquared_adj:>8.3f} {dart_ols_15.rsquared_adj:>8.3f} {dart_ols_20.rsquared_adj:>8.3f}")
print(f"{'coefficient (spills/storm day)':<28} {dart_ols_10.params[1]:>8.3f} {dart_ols_15.params[1]:>8.3f} {dart_ols_20.params[1]:>8.3f}") # params[1] is the slope coefficient in each single regressor model

# prints residuals by year across all three thresholds
print(f"{'year':<8} {'residual_10':>12} {'residual_15':>12} {'residual_20':>12}")
print('-' * 48)
for _, row in dart_annual.iterrows(): # one row per year
    print(f"{int(row['year']):<8} {row['residual_10']:>12.1f} {row['residual_15']:>12.1f} {row['residual_20']:>12.1f}")
# Out:
# Scale 1 OLS sensitivity check - threshold comparison:
# metric                           10mm     15mm     20mm
# --------------------------------------------------------
# R-squared                       0.865    0.956    0.986
# adj. R-squared                  0.797    0.933    0.979
# coefficient (spills/storm day)    4.940    8.701    8.159
# year      residual_10  residual_15  residual_20
# ------------------------------------------------
# 2021             -1.1          1.0          9.3
# 2022            -12.5         -5.2         -7.3
# 2023            -17.9        -12.8          1.5
# 2024             31.4         17.0         -3.5

# %% [markdown]
# > finding: at 10mm and 15mm, 2024 retains the largest positive residual (+31.4 and +17.0) - the anomaly is robust at thresholds most relevant to sewer capacity stress>at 20mm the finding breaks down - 2023 and 2024 recorded identical storm days (36) at this threshold, leaving the model no rainfall difference to work with>this is a data coincidence rather than a substantive challenge to the finding>testing upward only is correct - going below 10mm would capture light rainfall unlikely to stress overflow capacity

# %% [markdown]
# ### Section 4d - Scale 1 OLS Validation: Per-Catchment Residuals Across the SWW Region
# scale 1 validation - fits a separate OLS per catchment regressing `annual_spills_per_site` on `storm_days_10`, plots residuals over time for all 20 catchments with the Dart highlighted. Tests whether the synchronised 2022 dip in raw trajectories disappears once weather is stripped out. Saved to `outputs/scale1_validation_per_catchment_residuals.png`. Diagnostic chart - not included in narrative, available for transparency.

# %%
# per catchment OLS residuals after controlling for storm_days_10 - tests whether the 2022 dip in the raw trajectories disappears once weather is stripped out
years = [2021, 2022, 2023, 2024]  # list of years in the dataset - used for x axis ticks throughout sections 4 and 5
resid_records = []  # creates empty list to fill with one residuals dataframe per catchment
for catchment, group in sww_rivers.groupby('catchment_name'):
    data = group.sort_values('year').copy()
    if data['storm_days_10'].nunique() < 2:
        continue  # skips catchments with no variation in storm days - cannot fit OLS
    model = smf.ols('annual_spills_per_site ~ storm_days_10', data=data).fit()  # fits OLS on the four year panel for this catchment
    data['residual'] = model.resid  # residual = actual spills minus weather predicted spills
    resid_records.append(data[['catchment_name', 'year', 'residual']])

resid_df = pd.concat(resid_records, ignore_index=True)  # combines all catchments into one long dataframe

fig, ax = plt.subplots(figsize=(9, 6))

for catchment, group in resid_df.groupby('catchment_name'):
    data = group.sort_values('year')
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    ax.plot(data['year'], data['residual'], color=COLOUR_NATIONAL, linewidth=1, alpha=0.5)  # one grey line per catchment

dart_resid = resid_df[resid_df['catchment_name'] == 'Dart'].sort_values('year')
ax.plot(dart_resid['year'], dart_resid['residual'], color=COLOUR_DART, linewidth=2.5, label='Dart')  # dart drawn last so it sits on top

ax.axhline(0, color='black', linewidth=0.8, linestyle='--')  # reference line at zero - above means more spills than weather predicts, below means fewer
ax.set_xlabel('year', fontsize=11) # x axis label
ax.set_ylabel('residual spills per site (weather-adjusted)', fontsize=11) # y axis label
ax.set_title('weather-adjusted spills per site by SWW catchment, 2021–2024\nper-catchment OLS residuals after controlling for storm_days_10', fontsize=11) # two line title
ax.set_xticks(years) # ensures only integer years appear on x axis
ax.legend(fontsize=9) # adds legend distinguishing dart from other catchments
sns.despine(ax=ax) # removes top and right chart borders

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale1_validation_per_catchment_residuals.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale1_validation_per_catchment_residuals.png')
# Out:
# Saved: outputs/scale1_validation_per_catchment_residuals.png

# %%
# interactive plotly version of the 4d per catchment residuals chart - replicates the matplotlib version above with hover tooltips and legend toggle per catchment
fig = go.Figure()

for catchment, group in resid_df.groupby('catchment_name'):
    data = group.sort_values('year')
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    fig.add_trace(go.Scatter(
        x=data['year'], # year on x axis
        y=data['residual'], # weather adjusted residual on y axis
        mode='lines', # lines only - no markers
        name='other catchments', # all grey lines share one legend entry
        legendgroup='others', # groups all grey lines so one legend click toggles all of them together
        showlegend=(catchment == resid_df['catchment_name'].unique()[0]), # only first grey trace shows in legend - avoids 19 duplicate entries
        line=dict(color=COLOUR_NATIONAL, width=1), # grey colour matched to matplotlib version
        opacity=0.5, # matched to matplotlib alpha
        customdata=[[catchment]] * len(data), # passes catchment name into hover via customdata
        hovertemplate='<b>%{customdata[0]}</b><br>year: %{x}<br>residual: %{y:.2f}<extra></extra>',)) # hover shows catchment name, year and residual value

dart_resid = resid_df[resid_df['catchment_name'] == 'Dart'].sort_values('year')
fig.add_trace(go.Scatter(
    x=dart_resid['year'], # year on x axis
    y=dart_resid['residual'], # weather adjusted residual on y axis
    mode='lines', # lines only - no markers
    name='Dart', # separate legend entry for dart
    legendgroup='dart', # dart in its own legend group
    line=dict(color=COLOUR_DART, width=2.5), # blue colour and heavier line weight matched to matplotlib version
    hovertemplate='<b>Dart</b><br>year: %{x}<br>residual: %{y:.2f}<extra></extra>',)) # hover shows dart name, year and residual value

fig.add_hline(y=0, line_dash='dash', line_color='black', line_width=0.8) # reference line at zero - above means more spills than weather predicts, below means fewer

fig.update_layout(
    title='weather-adjusted spills per site by SWW catchment, 2021–2024<br><sup>per-catchment OLS residuals after controlling for storm_days_10</sup>', # matches matplotlib title
    xaxis_title='year', # matches matplotlib x axis label
    yaxis_title='residual spills per site (weather-adjusted)', # matches matplotlib y axis label
    height=500, # height in pixels
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    legend=dict(font=dict(size=9)),) # legend font size matched to matplotlib version

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', tickvals=[2021, 2022, 2023, 2024]) # integer year ticks only - matches matplotlib set_xticks
fig.update_yaxes(showgrid=True, gridcolor='#e5e5e5') # light grey grid lines on y axis

print('The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.
# ...

# %% [markdown]
# > finding: the synchronised 2022 dip visible in the raw trajectories largely disappears once weather is controlled for - comparing this chart against the indexed chart in section 5c makes this clearest: catchments that dipped in 2022 and recovered in 2023 do so because 2022 was a drier year across the whole sww region, not because infrastructure genuinely improved and then deteriorated>this is direct visual evidence that the 2022 dip was weather driven, and crucially it validates the scale 1 OLS approach: the fact that the same normalisation successfully strips the shared weather signal from all 20 catchments simultaneously confirms that the method is not an artefact of the darts small four datapoint sample, but reflects a genuine and consistent relationship between storm pressure and spill counts across the region

# %% [markdown]
# ### Section 4e - Scale 1 Validation: Combined Side-by-Side Figure for Narrative Embedding
# scale 1 validation - combines the section 4d residuals chart and the indexed raw trajectories chart into a single side-by-side PNG for narrative embedding. Not a new analysis. Saved to `outputs/scale1_validation_sidebyside.png`.

# %%
# combines scale 1 validation charts into a single side-by-side PNG for hackmd embedding
from PIL import Image  # loads saved PNGs for figure composition

img_indexed = Image.open(os.path.join(OUTPUTS_DIR, 'scale2_sww_trends_indexed.png'))  # left panel - indexed raw trajectories showing 2022 dip
img_residuals = Image.open(os.path.join(OUTPUTS_DIR, 'scale1_validation_per_catchment_residuals.png'))  # right panel - per-catchment residuals showing 2022 dip removed

fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # wide figure to hold both charts side by side

axes[0].imshow(img_indexed)  # plots indexed chart on left
axes[0].axis('off')  # removes axes - image display only

axes[1].imshow(img_residuals)  # plots residuals chart on right
axes[1].axis('off')  # removes axes - image display only

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale1_validation_sidebyside.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - output already shown as individual charts in sections 4d and 4e above
print('Saved: outputs/scale1_validation_sidebyside.png')
# Out:
# Saved: outputs/scale1_validation_sidebyside.png

# %% [markdown]
# ### Section 5 Inspection
# scale 2 - loads `sww_rivers.csv` and prints a per-catchment summary of `annual_spills_per_site` to confirm data structure before modelling.

# %%
sww_rivers = pd.read_csv(os.path.join('data', 'processed', 'sww_rivers.csv')) # loads sww_rivers.csv - built in section 3c - one row per catchment-year
print(f'shape: {sww_rivers.shape}') # prints the number of rows and columns in the dataset
print(f'columns: {list(sww_rivers.columns)}') # prints all column names
print(f'catchments: {sww_rivers["catchment_name"].nunique()}') # confirms 20 catchments
print(f'years: {sorted(sww_rivers["year"].unique())}') # confirms four years 2021-2024

summary_insp = (
    sww_rivers
    .groupby('catchment_name', sort=False) # groups by catchment - one group per catchment containing its four year rows
    .agg(
        mean_annual_spills=('annual_spills_per_site', 'mean'), # mean spills per site across the four years
        min_annual_spills=('annual_spills_per_site', 'min'), # lowest single year value
        max_annual_spills=('annual_spills_per_site', 'max'), # highest single year value
        mean_storm_days_10=('storm_days_10', 'mean')) # mean annual storm days across the four years
    .reset_index())

summary_insp['range_annual_spills'] = summary_insp['max_annual_spills'] - summary_insp['min_annual_spills'] # difference between highest and lowest single year value for each catchment
summary_insp = summary_insp.sort_values('mean_annual_spills', ascending=False).reset_index(drop=True) # sorts highest to lowest

print('per-catchment summary - sorted by mean annual_spills_per_site, highest to lowest:')
display(summary_insp.round(2))
# Out:
# shape: (80, 8)
# columns: ['catchment_name', 'year', 'annual_spill_total', 'n_sites', 'annual_spills_per_site', 'storm_days_10', 'storm_days_15', 'storm_days_20']
# catchments: 20
# years: [2021, 2022, 2023, 2024]
# per-catchment summary - sorted by mean annual_spills_per_site, highest to lowest:
#                   catchment_name  mean_annual_spills  min_annual_spills  \
# 0                Harbourne River              210.12             181.00
# 1                          Allen              137.83             103.67
# 2               Lower River Inny              110.05              95.20
# 3                           Dart              100.00              81.40
# 4   Torridge (Combe Lake to Lew)               93.94              79.25
# 5                           Tale               85.25              63.75
# 6                  Teign (Lower)               84.56              68.38
# 7             Lower River Lynher               74.75              49.78
# ...

# %% [markdown]
# > finding: harbourne river is a clear outlier about 1.5x worse than the next worst catchment (allen at 138)>dart sits fourth at 100 spills per site - bad but not the worst
# > finding: year on year variation is substantial in some catchments - allen and harbourne both show a range above 60 spills per site, while lower river tamar and torridge (lew to estuary) are relatively stable (range below 10)

# %% [markdown]
# ### Section 5a - Scale 2 Cross-Sectional OLS: Does storm pressure explain between-catchment variation?
# scale 2 - collapses `sww_rivers` to one row per catchment and fits OLS regressing mean `annual_spills_per_site` on mean `storm_days_10`. Tests whether storm pressure explains which catchments spill most. The near-zero fit justifies using a single regional temporal figure rather than per-catchment cross-sectional residuals for the ranking in section 5b - see narrative for interpretation. Also computes regional temporal OLS on year-level means and applies coefficients back to all 80 rows to produce `temporal_residual` for use throughout sections 5b–5d.

# %%
sww_cross = (sww_rivers.groupby('catchment_name', sort=False) # groups by catchment - one group per catchment
    .agg(
        mean_annual_spills_per_site=('annual_spills_per_site', 'mean'), # mean spills per site across the four years
        mean_storm_days_10=('storm_days_10', 'mean'), # mean annual storm days at 10mm threshold
        mean_storm_days_15=('storm_days_15', 'mean'), # mean annual storm days at 15mm threshold
        mean_storm_days_20=('storm_days_20', 'mean')) # mean annual storm days at 20mm threshold
    .reset_index())

sww_ols_10 = smf.ols('mean_annual_spills_per_site ~ mean_storm_days_10', data=sww_cross).fit() # fits OLS regressing mean annual spills per site on mean storm days
print('Scale 2 cross-sectional OLS summary (mean_storm_days_10):')
print(sww_ols_10.summary())

sww_cross['fitted'] = sww_ols_10.fittedvalues # stores the models predicted value for each catchment
sww_cross['residual'] = sww_ols_10.resid # stores the residual - positive means more spills than storm pressure alone predicts

print('\nresidual ranking - catchments sorted highest to lowest residual:')
display(sww_cross[['catchment_name', 'mean_annual_spills_per_site', 'mean_storm_days_10', 'fitted', 'residual']].sort_values('residual', ascending=False).reset_index(drop=True).round(2))
# Out:
# Scale 2 cross-sectional OLS summary (mean_storm_days_10):
#                                  OLS Regression Results
# ...
# Dep. Variable:     mean_annual_spills_per_site   R-squared:                       0.016
# Model:                                     OLS   Adj. R-squared:                 -0.038
# Method:                          Least Squares   F-statistic:                    0.2983
# Date:                         Thu, 07 May 2026   Prob (F-statistic):              0.592
# Time:                                 16:04:30   Log-Likelihood:                -103.11
# No. Observations:                           20   AIC:                             210.2
# Df Residuals:                               18   BIC:                             212.2
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# > finding: adjusted R-squared = -0.038, p = 0.592 - storm pressure explains almost none of the between-catchment variation in average spill rate. Geographically sensible - explained in writeup. The dominant driver of between-catchment variation is not weather based.
# > finding: the contrast with scale 1 is clean - on the Dart, storm pressure explains year-on-year variation well (adjusted R-squared = 0.797), but does not explain which rivers spill most relative to peers. It seems that, year to year the weather determines how bad it gets but river to river, the pipes determine how bad it is.
# > finding: cross-sectional residuals are close to the raw ranking but not identical - diagnostic only. The temporal residual ranking produced later in this section is what feeds section 5b and the narrative.

# %%
# computes regional storm days per year - average of storm_days_10 across all 20 catchments
regional_storm_days = (sww_rivers.groupby('year')['storm_days_10'].mean().reset_index().rename(columns={'storm_days_10': 'regional_storm_days_10'}))

# merges regional storm days onto the full 80 row panel
sww_rivers = sww_rivers.merge(regional_storm_days, on='year')

# collapses to one row per year - OLS fitted on year level means, so the model learns from temporal variation rsther than trying to find cross catchment differences from a regional value where this would be impossible
year_means = (sww_rivers.groupby('year')[['regional_storm_days_10', 'annual_spills_per_site']].mean().reset_index())

# fits OLS on the year level means - coefficient = extra predicted spills per site per additional regional storm day
temporal_model = smf.ols('annual_spills_per_site ~ regional_storm_days_10', data=year_means).fit()

# applies temporal model coefficient to all 80 rows - residual = actual spills per site minus what regional storm pressure that year predicts
sww_rivers['temporal_fitted'] = (temporal_model.params['Intercept']+ temporal_model.params['regional_storm_days_10'] * sww_rivers['regional_storm_days_10'])
sww_rivers['temporal_residual'] = sww_rivers['annual_spills_per_site'] - sww_rivers['temporal_fitted']

display(temporal_model.summary())  # displays full OLS summary table
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     annual_spills_per_site   R-squared:                       0.993
# Model:                                OLS   Adj. R-squared:                  0.989
# Method:                     Least Squares   F-statistic:                     267.0
# Date:                    Mon, 04 May 2026   Prob (F-statistic):            0.00372
# Time:                            13:37:33   Log-Likelihood:                -4.0887
# No. Observations:                       4   AIC:                             12.18
# Df Residuals:                           2   BIC:                             10.95
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# > finding: the temporal OLS fits extremely well on the four year level means - Rsquared = 0.993, p = 0.004 - statistically significant and confirming that year on year variation in average spills per site across the SWW region is almost entirely explained by regional storm day pressure
# > finding: the coefficient of 1.009 means each additional regional storm day is associated with approximately one extra spill per site on average across the region - this shared temporal weather signal is what the residuals chart below strips out, leaving each catchments position relative to peers more clearly visible.

# %% [markdown]
# ### Section 5b Inspection
# scale 2 - compares raw mean `annual_spills_per_site` ranking against the cross-sectional OLS residual ranking. Confirms the two are near-identical before using the temporal residual version in section 5b.

# %%
# adds rank columns to sww_cross - rank 1 = highest spilling/most anomalous catchment
sww_cross['raw_rank'] = sww_cross['mean_annual_spills_per_site'].rank(ascending=False).astype(int)  # rank by raw mean spills per site
sww_cross['residual_rank'] = sww_cross['residual'].rank(ascending=False).astype(int)  # rank by OLS residual after controlling for storm pressure
sww_cross['rank_change'] = sww_cross['raw_rank'] - sww_cross['residual_rank']  # positive means catchment moves up in residual ranking, negative means it moves down

rank_comparison = (
    sww_cross[['catchment_name', 'mean_annual_spills_per_site', 'raw_rank', 'residual', 'residual_rank', 'rank_change']]
    .sort_values('raw_rank')  # sorted by raw rank so the reader can scan down and see what changes (or doesnt change)
    .reset_index(drop=True)
    .round(2))

print('raw vs residual ranking comparison — sorted by raw rank:')
display(rank_comparison)
# Out:
# raw vs residual ranking comparison — sorted by raw rank:
#                   catchment_name  mean_annual_spills_per_site  raw_rank  \
# 0                Harbourne River                       210.12         1
# 1                          Allen                       137.83         2
# 2               Lower River Inny                       110.05         3
# 3                           Dart                       100.00         4
# 4   Torridge (Combe Lake to Lew)                        93.94         5
# 5                           Tale                        85.25         6
# 6                  Teign (Lower)                        84.56         7
# 7             Lower River Lynher                        74.75         8
# 8                        Walkham                        73.10         9
# 9                          Meavy                        67.04        10
# 10                     Lower Axe                        60.56        11
# ...

# %% [markdown]
# > finding: the top half of the ranking is near identical between raw and residual - the top seven catchments all hold their position or move by at most one place>harbourne river and allen remain the clear outliers at positions one and two in both rankings
# > finding: there is more movement in the bottom half - lower river tavy drops three places (16th to 19th) and lower culm rises three places (18th to 15th) once storm pressure is controlled for>these shifts reflect catchments where local rainfall variation partially explains raw spill levels
# > finding: the dart moves one place (4th to 5th) - a negligible change that does not affect the interpretation>using the residual version is the more analytically defensible choice and does not materially distort the picture

# %% [markdown]
# ### Section 5b - Scale 2 Ranked Bar Chart: Weather-Adjusted Spills Per Site by Catchment
# scale 2 - plots mean temporal OLS residuals per catchment as a horizontal bar chart, ranked highest to lowest. Dart highlighted in blue. Saved to `outputs/scale2_sww_ranking.png`.

# %%
# collapses temporal_residual to one row per catchment using mean across all four years
sww_temporal_ranks = (sww_rivers.groupby('catchment_name')['temporal_residual'].mean().reset_index().rename(columns={'temporal_residual': 'mean_temporal_residual'}))

fig, ax = plt.subplots(figsize=(9, 7)) # creates figure
plot_data = sww_temporal_ranks.sort_values('mean_temporal_residual', ascending=True)  # sorts ascending so the highest residual catchment appears at the top of the horizontal bar chart
colours = [COLOUR_DART if c == 'Dart' else COLOUR_SWW for c in plot_data['catchment_name']]  # assigns blue to the dart bar and orange to all others

ax.barh(plot_data['catchment_name'], plot_data['mean_temporal_residual'], color=colours)  # plots one horizontal bar per catchment - length represents mean temporal OLS residual
ax.axvline(0, color='black', linewidth=0.8, linestyle='--')  # reference line at zero - positive means more spills than regional weather predicts, negative means fewer

ax.set_xlabel('residual spills per site (regional weather-adjusted)', fontsize=11)  # x axis label
ax.set_ylabel('catchment', fontsize=11)  # y axis label
ax.set_title('weather-adjusted spills per site by SWW catchment, 2021–2024\nregional temporal OLS residuals — top 20 catchments', fontsize=11)  # two line title

handles = [plt.Rectangle((0, 0), 1, 1, color=COLOUR_DART), plt.Rectangle((0, 0), 1, 1, color=COLOUR_SWW)]  # manually creates two small coloured rectangles to act as legend symbols
ax.legend(handles, ['Dart', 'other SWW catchments'], fontsize=9)  # adds legend

sns.despine(ax=ax)  # removes top and right chart borders
plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale2_sww_ranking.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale2_sww_ranking.png')
# Out:
# Saved: outputs/scale2_sww_ranking.png

# %%
# interactive plotly version of the section 5b residual bar chart - replicates the matplotlib version made above with hover tooltips showing exact residual values per catchment
plot_data = sww_temporal_ranks.sort_values('mean_temporal_residual', ascending=True)  # sorts ascending so highest residual catchment appears at the top of the horizontal bar chart
bar_colours = [COLOUR_DART if c == 'Dart' else COLOUR_SWW for c in plot_data['catchment_name']]  # assigns blue to dart and orange to all others
fig = go.Figure()

fig.add_trace(go.Bar(
    x=plot_data['mean_temporal_residual'], # mean temporal residual on x axis - determines bar length and direction
    y=plot_data['catchment_name'], # catchment names on y axis - one bar per catchment
    orientation='h', # horizontal bar chart to match matplotlib version
    marker_color=bar_colours, # colours matched to matplotlib version
    hovertemplate='<b>%{y}</b><br>residual: %{x:.2f}<extra></extra>',)) # hover shows catchment name and residual to 2 decimal places

fig.add_vline(x=0, line_dash='dash', line_color='black', line_width=1)  # vertical dashed line at zero - positive means more spills than regional weather predicts

fig.update_layout(
    title='weather-adjusted spills per site by SWW catchment, 2021–2024<br><sup>regional temporal OLS residuals — top 20 catchments</sup>',  # matches matplotlib title
    xaxis_title='residual spills per site (regional weather-adjusted)', # matches matplotlib x axis label
    yaxis_title=None, # no y axis label needed - catchment names are self explanatory
    height=550, # height in pixels - chosen to give each bar comfortable spacing
    margin=dict(l=180, r=30, t=80, b=50), # left margin extended to accommodate long catchment names
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white',  # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    showlegend=False,) # no legend needed - dart is identifiable by colour and hover tooltip
fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', zeroline=False) # light grey grid lines on x axis - zeroline handled by vline above
fig.update_yaxes(showgrid=False) # no grid lines on y axis

print('The chart below is interactive - hover over any bar to see exact values.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any bar to see exact values.

# %% [markdown]
# > finding: harbourne river and allen are clear outliers at the top of the weather adjusted ranking, with mean temporal residuals of +136.53 and +64.24 spills per site respectively - spilling far more than regional weather pressure alone would predict across all four years
# > finding: the dart sits fourth with a residual of +26.41, comfortably in the upper half of the distribution but not the most anomalous catchment in the region
# > finding: the bottom half of the ranking shows a long tail of negative residuals - these catchments spill less than regional weather pressure predicts, with lower river otter the furthest below expectation at -48.46

# %% [markdown]
# ### Section 5c - Scale 2 Trend Analysis: Annual Spills Per Site Trajectories 2021–2024
# scale 2 - plots `annual_spills_per_site` trajectories for all 20 catchments as two overlay charts: absolute values and indexed to 2021=100. Dart highlighted in blue. Diagnostic charts - not included in narrative, available for transparency.

# %%
# overlay chart - all 20 catchments as grey lines, dart highlighted in blue on top
fig, ax = plt.subplots(figsize=(9, 6)) # creates figure

for catchment, group in sww_rivers.groupby('catchment_name'):
    data = group.sort_values('year')
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    ax.plot(data['year'], data['annual_spills_per_site'], color=COLOUR_NATIONAL, linewidth=1, alpha=0.5)  # one grey line per catchment - alpha reduces visual clutter (trabsparency)

dart_data = sww_rivers[sww_rivers['catchment_name'] == 'Dart'].sort_values('year')
ax.plot(dart_data['year'], dart_data['annual_spills_per_site'], color=COLOUR_DART, linewidth=2.5, label='Dart')  # dart drawn last so it sits on top of all grey lines

ax.set_xlabel('year', fontsize=11) # x axis label
ax.set_ylabel('annual spills per site', fontsize=11) # y axis label
ax.set_title('annual spills per site by SWW catchment, 2021–2024\nDart highlighted against all 20 catchments', fontsize=11) # two line title
ax.set_xticks(years) # ensures only integer years appear on x axis
ax.legend(fontsize=9) # adds legend distinguishing dart from other catchments
sns.despine(ax=ax) # removes top and right chart borders

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale2_sww_trends_overlay.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale2_sww_trends_overlay.png')
# Out:
# Saved: outputs/scale2_sww_trends_overlay.png

# %%
# interactive plotly version of the section 5c absolute overlay - replicates the matplotlib version above with hover tooltips and legend toggle per catchment
fig = go.Figure()

for catchment, group in sww_rivers.groupby('catchment_name'):
    data = group.sort_values('year')
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    fig.add_trace(go.Scatter(
        x=data['year'], # year on x axis
        y=data['annual_spills_per_site'], # spills per site on y axis
        mode='lines', # lines only - no markers
        name='other catchments', # all grey lines share one legend entry
        legendgroup='others', # groups all grey lines so one legend click toggles all of them together
        showlegend=(catchment == sww_rivers['catchment_name'].unique()[0]), # only first grey trace shows in legend - avoids 19 duplicate entries
        line=dict(color=COLOUR_NATIONAL, width=1), # grey colour matched to matplotlib version
        opacity=0.5, # matched to matplotlib alpha
        customdata=[[catchment]] * len(data), # passes catchment name into hover via customdata
        hovertemplate='<b>%{customdata[0]}</b><br>year: %{x}<br>spills per site: %{y:.2f}<extra></extra>',)) # hover shows catchment name, year, and value

dart_data = sww_rivers[sww_rivers['catchment_name'] == 'Dart'].sort_values('year')
fig.add_trace(go.Scatter(
    x=dart_data['year'], # year on x axis
    y=dart_data['annual_spills_per_site'], # spills per site on y axis
    mode='lines', # lines only - no markers
    name='Dart', # separate legend entry for dart
    legendgroup='dart', # dart in its own legend group
    line=dict(color=COLOUR_DART, width=2.5), # blue colour and heavier line weight matched to matplotlib version
    hovertemplate='<b>Dart</b><br>year: %{x}<br>spills per site: %{y:.2f}<extra></extra>',)) # hover shows dart name, year, and value

fig.update_layout(
    title='annual spills per site by SWW catchment, 2021–2024<br><sup>Dart highlighted against all 20 catchments</sup>', # matches matplotlib title
    xaxis_title='year', # matches matplotlib x axis label
    yaxis_title='annual spills per site', # matches matplotlib y axis label
    height=500, # height in pixels
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    legend=dict(font=dict(size=9)),) # legend font size matched to matplotlib version

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', tickvals=[2021, 2022, 2023, 2024]) # integer year ticks only - matches matplotlib set_xticks
fig.update_yaxes(showgrid=True, gridcolor='#e5e5e5') # light grey grid lines on y axis

print('The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.
# ...

# %% [markdown]
# > finding: the majority of catchments show a broadly flat or rising trajectory across 2021-2024 - the dart climbs steadily from around 80 spills per site in 2021 to around 115 in 2024, crossing from the lower half of the distribution into the upper half over the period
# > finding: two catchments sit visibly above the rest throughout - their absolute levels are so high that most other catchments cluster in the lower half of the chart regardless of trend direction

# %%
# indexed overlay - each catchment rebased to 100 in 2021, showing percentage change from baseline - removes the effect of different starting levels and makes trajectories directly comparable
fig, ax = plt.subplots(figsize=(9, 6)) # creates figure

for catchment, group in sww_rivers.groupby('catchment_name'):
    data = group.sort_values('year').copy()
    base = data.loc[data['year'] == 2021, 'annual_spills_per_site'].values[0]  # 2021 value as baseline
    data['indexed'] = (data['annual_spills_per_site'] / base) * 100  # rebases each catchment to 100 in 2021
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    ax.plot(data['year'], data['indexed'], color=COLOUR_NATIONAL, linewidth=1, alpha=0.5)  # one grey line per catchment

dart_data = sww_rivers[sww_rivers['catchment_name'] == 'Dart'].sort_values('year').copy()
dart_base = dart_data.loc[dart_data['year'] == 2021, 'annual_spills_per_site'].values[0] # dart 2021 baseline
dart_data['indexed'] = (dart_data['annual_spills_per_site'] / dart_base) * 100  # rebases dart to 100 in 2021
ax.plot(dart_data['year'], dart_data['indexed'], color=COLOUR_DART, linewidth=2.5, label='Dart')  # dart drawn last so it sits on top

ax.axhline(100, color='black', linewidth=0.8, linestyle='--')  # reference line at 100 - above means worse than 2021 below means better
ax.set_xlabel('year', fontsize=11) # x axis label
ax.set_ylabel('index (2021 = 100)', fontsize=11) # y axis label
ax.set_title('annual spills per site by SWW catchment, 2021–2024\nindexed to 2021 = 100', fontsize=11) # two line title
ax.set_xticks(years) # ensures only integer years appear on x axis
ax.legend(fontsize=9) # adds legend distinguishing dart from other catchments
sns.despine(ax=ax) # removes top and right chart borders

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale2_sww_trends_indexed.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale2_sww_trends_indexed.png')
# Out:
# Saved: outputs/scale2_sww_trends_indexed.png

# %%
# interactive plotly version of the section 5c indexed overlay - replicates the matplotlib version above with hover tooltips and legend toggle per catchment
fig = go.Figure()

for catchment, group in sww_rivers.groupby('catchment_name'):
    data = group.sort_values('year').copy()
    base = data.loc[data['year'] == 2021, 'annual_spills_per_site'].values[0] # 2021 value as baseline
    data['indexed'] = (data['annual_spills_per_site'] / base) * 100 # rebases each catchment to 100 in 2021
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    fig.add_trace(go.Scatter(
        x=data['year'], # year on x axis
        y=data['indexed'], # indexed value on y axis
        mode='lines', # lines only - no markers
        name='other catchments', # all grey lines share one legend entry
        legendgroup='others', # groups all grey lines so one legend click toggles all of them together
        showlegend=(catchment == sww_rivers['catchment_name'].unique()[0]), # only first grey trace shows in legend - avoids 19 duplicate entries
        line=dict(color=COLOUR_NATIONAL, width=1), # grey colour matched to matplotlib version
        opacity=0.5, # matched to matplotlib alpha
        customdata=[[catchment]] * len(data), # passes catchment name into hover via customdata
        hovertemplate='<b>%{customdata[0]}</b><br>year: %{x}<br>index: %{y:.2f}<extra></extra>',)) # hover shows catchment name, year, and indexed value

dart_data = sww_rivers[sww_rivers['catchment_name'] == 'Dart'].sort_values('year').copy()
dart_base = dart_data.loc[dart_data['year'] == 2021, 'annual_spills_per_site'].values[0] # dart 2021 baseline
dart_data['indexed'] = (dart_data['annual_spills_per_site'] / dart_base) * 100 # rebases dart to 100 in 2021
fig.add_trace(go.Scatter(
    x=dart_data['year'], # year on x axis
    y=dart_data['indexed'], # indexed value on y axis
    mode='lines', # lines only - no markers
    name='Dart', # separate legend entry for dart
    legendgroup='dart', # dart in its own legend group
    line=dict(color=COLOUR_DART, width=2.5), # blue colour and heavier line weight matched to matplotlib version
    hovertemplate='<b>Dart</b><br>year: %{x}<br>index: %{y:.2f}<extra></extra>',)) # hover shows dart name, year, and indexed value

fig.add_hline(y=100, line_dash='dash', line_color='black', line_width=0.8) # reference line at 100 - above means worse than 2021, below means better

fig.update_layout(
    title='annual spills per site by SWW catchment, 2021–2024<br><sup>indexed to 2021 = 100</sup>', # matches matplotlib title
    xaxis_title='year', # matches matplotlib x axis label
    yaxis_title='index (2021 = 100)', # matches matplotlib y axis label
    height=500, # height in pixels
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    legend=dict(font=dict(size=9)),) # legend font size matched to matplotlib version

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', tickvals=[2021, 2022, 2023, 2024]) # integer year ticks only - matches matplotlib set_xticks
fig.update_yaxes(showgrid=True, gridcolor='#e5e5e5') # light grey grid lines on y axis

print('The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.
# ...

# %% [markdown]
# > finding: indexed to 2021 = 100, the dart has increased about 45% from its baseline by 2024 - one of the more consistent upward trajectories in the group, with no dip in 2022 unlike most other catchments
# > finding: most catchments dip below 100 in 2022 before rising again - the dart is a notable exception, rising almost monotonically throughout the period
# > finding: catchments starting from a low 2021 baseline can show amplified percentage swings - lines showing the most extreme movements should be read with this in mind

# %% [markdown]
# ### Section 5d - Scale 2 Regional Weather-Adjusted Rankings: Are Catchment Positions Persistent Over Time?
# scale 2 - plots `temporal_residual` trajectories for all 20 catchments across 2021–2024 using the regional weather adjustment built in section 5a. Tests whether cross-sectional rankings are stable across years or sensitive to which year is examined. Saved to `outputs/scale2_sww_trends_regional_residuals.png`.

# %%
# regional temporal OLS residuals overlay - strips shared year on year weather effect, leaving each catchments position relative to peers
fig, ax = plt.subplots(figsize=(9, 6))

for catchment, group in sww_rivers.groupby('catchment_name'):
    data = group.sort_values('year')
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    ax.plot(data['year'], data['temporal_residual'], color=COLOUR_NATIONAL, linewidth=1, alpha=0.5)  # one grey line per catchment

dart_data = sww_rivers[sww_rivers['catchment_name'] == 'Dart'].sort_values('year')
ax.plot(dart_data['year'], dart_data['temporal_residual'], color=COLOUR_DART, linewidth=2.5, label='Dart')  # dart drawn last so it sits on top

ax.axhline(0, color='black', linewidth=0.8, linestyle='--')  # reference line at zero - above means more spills than regional weather predicts
ax.set_xlabel('year', fontsize=11)
ax.set_ylabel('residual spills per site (regional weather-adjusted)', fontsize=11)
ax.set_title('weather-adjusted spills per site by SWW catchment, 2021–2024\ntemporal OLS residuals after controlling for regional storm days', fontsize=11)
ax.set_xticks([2021, 2022, 2023, 2024])
ax.legend(fontsize=9)
sns.despine(ax=ax)

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale2_sww_trends_regional_residuals.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ - interactive plotly version shown below
print('Saved: outputs/scale2_sww_trends_regional_residuals.png')
# Out:
# Saved: outputs/scale2_sww_trends_regional_residuals.png

# %%
# interactive plotly version of the section 5c regional residuals chart - replicates the matplotlib version above with hover tooltips and legend toggle per catchment
fig = go.Figure()

for catchment, group in sww_rivers.groupby('catchment_name'):
    data = group.sort_values('year')
    if catchment == 'Dart':
        continue  # dart plotted last so it renders on top of all grey lines
    fig.add_trace(go.Scatter(
        x=data['year'], # year on x axis
        y=data['temporal_residual'], # regional weather adjusted residual on y axis
        mode='lines', # lines only - no markers
        name='other catchments', # all grey lines share one legend entry
        legendgroup='others', # groups all grey lines so one legend click toggles all of them together
        showlegend=(catchment == sww_rivers['catchment_name'].unique()[0]), # only first grey trace shows in legend - avoids 19 duplicates
        line=dict(color=COLOUR_NATIONAL, width=1), # grey colour matched to matplotlib version
        opacity=0.5, # matched to matplotlib alpha
        customdata=[[catchment]] * len(data), # passes catchment name into hover via customdata
        hovertemplate='<b>%{customdata[0]}</b><br>year: %{x}<br>residual: %{y:.2f}<extra></extra>',)) # hover shows catchment name, year, and residual value

dart_data = sww_rivers[sww_rivers['catchment_name'] == 'Dart'].sort_values('year')

fig.add_trace(go.Scatter(
    x=dart_data['year'], # year on x axis
    y=dart_data['temporal_residual'], # regional weather adjusted residual on y axis
    mode='lines', # lines only - no markers
    name='Dart', # separate legend entry for dart
    legendgroup='Dart', # dart in its own legend group
    line=dict(color=COLOUR_DART, width=2.5), # blue colour and heavier line weight matched to matplotlib version
    hovertemplate='<b>Dart</b><br>year: %{x}<br>residual: %{y:.2f}<extra></extra>',)) # hover shows dart name, year, and residual value

fig.add_hline(y=0, line_dash='dash', line_color='black', line_width=0.8) # reference line at zero - above means more spills than regional weather predicts, below means fewer

fig.update_layout(
    title='weather-adjusted spills per site by SWW catchment, 2021–2024<br><sup>temporal OLS residuals after controlling for regional storm days</sup>', # matches matplotlib title
    xaxis_title='year', # matches matplotlib x axis label
    yaxis_title='residual spills per site (regional weather-adjusted)', # matches matplotlib y axis label
    height=500, # height in pixels
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    legend=dict(font=dict(size=9)),) # legend font size matched to matplotlib version

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', tickvals=[2021, 2022, 2023, 2024]) # integer year ticks only - matches matplotlib set_xticks
fig.update_yaxes(showgrid=True, gridcolor='#e5e5e5') # light grey grid lines on y axis

print('The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.

# %% [markdown]
# > finding: catchment rankings are largely stable across all four years once the shared regional weather effect is stripped out - catchments above zero in 2021 broadly remain above zero through to 2024 and those below remain below>this confirms that between catchment differences in spill rates are structural and persistent
# > finding: this stability validates the use of four year average performance in the cross sectional analysis - a catchments mean spills per site is a reliable representation of its underlying position
# > finding: the dart sits consistently above zero throughout and its residual is rising - it spills more than regional weather pressure predicts in every year and that gap is widening>this is not a one year anomaly but a persistent structural pattern relative to its SWW peers - the dart appears to be worsening
# > finding: the two outlier catchments visible at the top are consistent with section 5b - harbourne river and allen sit far above the rest in every year, confirming their elevated cross sectional ranking is not a statistical artefact of averaging

# %% [markdown]
# ### Section 6a - Scale 3 Coverage Check
# scale 3 - inspects `national_summary.csv` for monitored site expansion per company across 2021–2024. Identifies companies where coverage growth means temporal trends must be interpreted cautiously - particularly Anglian Water (+72.1%), which is excluded from temporal analysis as a result. See narrative for full reasoning.

# %%
# loads national_summary.csv and inspects monitored_sites per company per year - identifies any companies with large coverage expansion
national_df = pd.read_csv(os.path.join(PROCESSED_DIR, 'national_summary.csv'))  # reloads from disk - ensures section 6 analysis is not dependent on section 3e still being in memory

# pivots so each row is a company and each column is a year - makes it easy to compare monitored_sites across years at a glance
sites_pivot = national_df.pivot_table(index='company', columns='year', values='monitored_sites', aggfunc='first')
sites_pivot['range'] = sites_pivot.max(axis=1) - sites_pivot.min(axis=1)  # max minus min across years - zero means perfectly stable, large value means significant expansion
sites_pivot['pct_change'] = ((sites_pivot[2024] - sites_pivot[2021]) / sites_pivot[2021] * 100).round(1)  # percentage change from 2021 to 2024 - clearest summary of expansion magnitude
sites_pivot = sites_pivot.sort_values('pct_change', ascending=False)  # sorts highest expansion first so any problematic companies are immediately visible

print('monitored_sites by company and year (sorted by % change 2021-2024):')
print(sites_pivot.to_string())
# Out:
# monitored_sites by company and year (sorted by % change 2021-2024):
# year                      2021  2022  2023  2024  range  pct_change
# company
# Anglian Water (AWS)        834  1054  1423  1435    601        72.1
# Thames Water (TW)          461   472   610   585    149        26.9
# South West Water (SWW)    1093  1323  1342  1361    268        24.5
# Wessex Water (WSSX)       1048  1182  1295  1295    247        23.6
# United Utilities (UU)     1954  1971  2147  2244    290        14.8
# Northumbrian Water (NW)   1440  1463  1546  1551    111         7.7
# Yorkshire Water (YWS)     2087  2118  2165  2171     84         4.0
# Southern Water (SW)        943   939   962   971     32         3.0
# Severn Trent Water (SvT)  2412  2438  2421  2445     33         1.4

# %% [markdown]
# > finding: anglian water shows the largest coverage expansion at +72.1% (834 to 1435 monitored sites 2021-2024)>thames water (+26.9%), sww (+24.5%), and wessex water (+23.6%) also show substantial growth>southern water (+3.0%) and severn trent (+1.4%) are the most stable>the remaining companies fall between these extremes

# %% [markdown]
# ### Section 6b - Scale 3 Cross-Sectional OLS: Does regional rainfall explain between-company variation?
# scale 3 - collapses `national_df` to one row per company and fits OLS regressing mean `spills_per_monitored_site` on mean `annual_rainfall_mm`. Tests whether regional climate differences explain which companies report the most spills per site. `annual_rainfall_mm` used in place of `storm_days`. See narrative for interpretation and limitations of the shared SWW/Wessex rainfall figure.

# %%
# collapses national_df to one row per company - means across 2021-2024 for both spills per monitored site and annual rainfall
national_cross = (
    national_df
    .groupby('company', sort=False)  # groups by company - one group per company containing its four year rows
    .agg(
        mean_spills_per_monitored_site=('spills_per_monitored_site', 'mean'),  # mean spills per monitored site across 2021-2024
        mean_annual_rainfall_mm=('annual_rainfall_mm', 'mean'))  # mean annual rainfall in mm across 2021-2024
    .reset_index())

national_ols = smf.ols('mean_spills_per_monitored_site ~ mean_annual_rainfall_mm', data=national_cross).fit()  # fits OLS regressing mean spills per monitored site on mean annual rainfall
print('Scale 3 cross-sectional OLS summary (mean_annual_rainfall_mm):')
print(national_ols.summary())

national_cross['fitted'] = national_ols.fittedvalues  # stores the models predicted value for each company
national_cross['residual'] = national_ols.resid  # stores the residual - positive means more spills than rainfall alone predicts

print('\nresidual ranking - companies sorted highest to lowest residual:')
display(national_cross[['company', 'mean_spills_per_monitored_site', 'mean_annual_rainfall_mm', 'fitted', 'residual']].sort_values('residual', ascending=False).reset_index(drop=True).round(2))
# Out:
# Scale 3 cross-sectional OLS summary (mean_annual_rainfall_mm):
#                                   OLS Regression Results
# ...
# Dep. Variable:     mean_spills_per_monitored_site   R-squared:                       0.534
# Model:                                        OLS   Adj. R-squared:                  0.468
# Method:                             Least Squares   F-statistic:                     8.035
# Date:                            Mon, 04 May 2026   Prob (F-statistic):             0.0252
# Time:                                    13:37:34   Log-Likelihood:                -24.984
# No. Observations:                               9   AIC:                             53.97
# Df Residuals:                                   7   BIC:                             54.36
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# > finding: adjusted R-squared = 0.468, p = 0.025 — unlike at scale 2, regional rainfall explains a meaningful share of between-company variation in spills per monitored site. Wetter-region companies tend to report more spills per site and the relationship is statistically significant.
# > finding: Yorkshire Water has the largest positive residual at +5.37, SWW second at +3.72, and United Utilities third at +3.57 — all three spill more per monitored site than their regional rainfall alone would predict.
# > finding: Wessex Water has the largest negative residual at -7.57 - it spills substantially less per monitored site than rainfall would predict, despite being mapped to the same Met Office region as SWW — caveat to this finding discussed in narrative.

# %% [markdown]
# ### Section 6c.1 - Scale 3 Ranked Bar Chart: Mean Spills Per Monitored Site by Company
# scale 3 - plots mean `spills_per_monitored_site` for each of the nine English water companies as a horizontal bar chart, ranked highest to lowest. SWW highlighted in orange. Saved to `outputs/scale3_national_ranking.png`. Raw ranking not included in narrative, available for transparency.

# %%
fig, ax = plt.subplots(figsize=(9, 6))  # creates figure

plot_data = national_cross.sort_values('mean_spills_per_monitored_site', ascending=True)  # sorts ascending so the highest spilling company appears at the top of the horizontal bar chart
colours = [COLOUR_SWW if 'SWW' in c else COLOUR_NATIONAL for c in plot_data['company']]  # assigns orange to SWW and grey to all others - list comprehension iterates through company names in plot order

ax.barh(plot_data['company'], plot_data['mean_spills_per_monitored_site'], color=colours)  # plots one horizontal bar per company - length represents mean spills per monitored site across 2021-2024

ax.set_xlabel('mean spills per monitored site (2021–2024)', fontsize=11)  # x axis label
ax.set_ylabel('company', fontsize=11)  # y axis label
ax.set_title('mean spills per monitored site by water company, 2021–2024', fontsize=11)  # title

handles = [plt.Rectangle((0, 0), 1, 1, color=COLOUR_SWW), plt.Rectangle((0, 0), 1, 1, color=COLOUR_NATIONAL)]  # manually creates two small coloured rectangles to act as legend symbols
ax.legend(handles, ['South West Water', 'other companies'], fontsize=9)  # adds legend distinguishing SWW from the rest

sns.despine(ax=ax)  # removes top and right chart borders
plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale3_national_ranking.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale3_national_ranking.png')
# Out:
# Saved: outputs/scale3_national_ranking.png

# %%
# interactive plotly version of the section 6c.1 raw ranking bar chart - replicates the matplotlib version above with hover tooltips showing exact values per company
plot_data = national_cross.sort_values('mean_spills_per_monitored_site', ascending=True) # sorts ascending so the highest spilling company appears at the top
bar_colours = [COLOUR_SWW if 'SWW' in c else COLOUR_NATIONAL for c in plot_data['company']] # assigns orange to SWW and grey to all others

fig = go.Figure()

fig.add_trace(go.Bar(
    x=plot_data['mean_spills_per_monitored_site'], # mean spills per monitored site on x axis - determines bar length
    y=plot_data['company'], # company names on y axis - one bar per company
    orientation='h', # horizontal bar chart to match matplotlib version
    marker_color=bar_colours, # colours matched to matplotlib version
    hovertemplate='<b>%{y}</b><br>mean spills per monitored site: %{x:.2f}<extra></extra>',)) # hover shows company name and value to 2 decimal places

fig.update_layout(
    title='mean spills per monitored site by water company, 2021–2024', # matches matplotlib title
    xaxis_title='mean spills per monitored site (2021–2024)', # matches matplotlib x axis label
    yaxis_title=None, # no y axis label needed - company names are self explanatory
    height=450, # height in pixels - fewer bars than section 5b so less height needed
    margin=dict(l=200, r=30, t=60, b=50), # left margin extended to accommodate company names
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    showlegend=False,) # no legend needed - SWW is identifiable by colour and hover tooltip

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', zeroline=False) # light grey grid lines on x axis
fig.update_yaxes(showgrid=False) # no grid lines on y axis

print('The chart below is interactive - hover over any bar to see exact values.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any bar to see exact values.
# ...

# %% [markdown]
# > finding: SWW ranks second highest nationally at about 38 mean spills per monitored site across 2021-2024, behind only united utilities at just under 40
# > finding: the gap between the top two companies (UU and SWW) and the rest of the field is notable - yorkshire water at 31.6 is the next closest, with the remaining six companies clustered between 23 and 29 spills per monitored site
# > finding: severn trent and anglian water report the lowest mean spills per monitored site at approximately 23 each

# %% [markdown]
# ### Section 6c.2 - Scale 3 Rainfall-Adjusted Ranking: Residuals from Cross-Sectional OLS
# scale 3 - plots residuals from the section 6b OLS as a horizontal bar chart, ranked highest to lowest. Shows which companies spill more or less than their regional rainfall alone would predict. Saved to `outputs/scale3_national_ranking_adjusted.png`.

# %%
fig, ax = plt.subplots(figsize=(9, 6))  # creates figure

plot_data_resid = national_cross.sort_values('residual', ascending=True)  # sorts ascending so the largest positive residual appears at the top
colours_resid = [COLOUR_SWW if 'SWW' in c else COLOUR_NATIONAL for c in plot_data_resid['company']]  # assigns orange to SWW and grey to all others

ax.barh(plot_data_resid['company'], plot_data_resid['residual'], color=colours_resid)  # plots one horizontal bar per company - length represents residual from the cross sectional OLS

ax.axvline(0, color='black', linewidth=0.8, linestyle='--')  # vertical line at zero - companies to the right spill more than rainfall predicts companies to the left spill less
ax.set_xlabel('residual: actual minus rainfall-predicted spills per monitored site (2021–2024)', fontsize=11)  # x axis label
ax.set_ylabel('company', fontsize=11)  # y axis label
ax.set_title('spills per monitored site relative to regional rainfall expectation\nmean 2021–2024, residuals from OLS', fontsize=11)  # two line title

handles = [plt.Rectangle((0, 0), 1, 1, color=COLOUR_SWW), plt.Rectangle((0, 0), 1, 1, color=COLOUR_NATIONAL)]  # manually creates two small coloured rectangles to act as legend symbols
ax.legend(handles, ['South West Water', 'other companies'], fontsize=9)  # adds legend

sns.despine(ax=ax)  # removes top and right chart borders
plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale3_national_ranking_adjusted.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale3_national_ranking_adjusted.png')
# Out:
# Saved: outputs/scale3_national_ranking_adjusted.png

# %%
# interactive plotly version of the section 6c.2 rainfall adjusted ranking bar chart - replicates the matplotlib version above with hover tooltips showing exact residuals per company
plot_data_resid = national_cross.sort_values('residual', ascending=True) # sorts ascending so the largest positive residual appears at the top
bar_colours_resid = [COLOUR_SWW if 'SWW' in c else COLOUR_NATIONAL for c in plot_data_resid['company']] # assigns orange to SWW and grey to all others

fig = go.Figure()

fig.add_trace(go.Bar(
    x=plot_data_resid['residual'], # residual values on x axis - determines bar length and direction
    y=plot_data_resid['company'], # company names on y axis - one bar per company
    orientation='h', # horizontal bar chart to match matplotlib version
    marker_color=bar_colours_resid, # colours matched to matplotlib version
    hovertemplate='<b>%{y}</b><br>residual: %{x:.2f}<extra></extra>',)) # hover shows company name and residual to 2 decimal places

fig.add_vline(x=0, line_dash='dash', line_color='black', line_width=1) # vertical dashed line at zero - positive means more spills than rainfall predicts

fig.update_layout(
    title='spills per monitored site relative to regional rainfall expectation<br><sup>mean 2021–2024, residuals from OLS</sup>', # matches matplotlib title
    xaxis_title='residual: actual minus rainfall-predicted spills per monitored site (2021–2024)', # matches matplotlib x axis label
    yaxis_title=None, # no y axis label needed - company names are self explanatory
    height=450, # height in pixels
    margin=dict(l=200, r=30, t=80, b=50), # left margin extended to accommodate company names
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    showlegend=False,) # no legend needed - SWW is identifiable by colour and hover tooltip

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', zeroline=False) # light grey grid lines on x axis - zeroline handled by vline above
fig.update_yaxes(showgrid=False) # no grid lines on y axis

print('The chart below is interactive - hover over any bar to see exact values.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any bar to see exact values.
# ...

# %% [markdown]
# > finding: once regional rainfall is controlled for, SWW ranks second among the nine companies - behind yorkshire water (+5.37) and ahead of united utilities (+3.57) - confirming that SWW spills more per monitored site than its climate alone would predict
# > finding: the ranking shifts notably relative to the raw chart - united utilities drops from first to third once rainfall is accounted for, suggesting a meaningful share of its high raw spill rate reflects its wetter operating region rather than infrastructure underperformance
# > finding: wessex water has the largest negative residual at -7.57 - it performs substantially better than rainfall would predict, though as noted in section 6b this comparison is complicated by wessex and SWW sharing an identical rainfall figure despite potentially differing sub regional climates

# %% [markdown]
# ### Section 6d - Scale 3 Trend Analysis: Spills Per Monitored Site Trajectories 2021–2024
# scale 3 - plots `spills_per_monitored_site` trajectories for eight companies (Anglian Water excluded) with SWW highlighted. Also plots indexed trajectories and rainfall-adjusted residual trajectories. Fits raw and rainfall-adjusted trend slopes per company. `annual_rainfall_mm` used as the within-company weather proxy as noted in the narrative. All slopes indicative only with four data points per company.

# %%
# defines the eight companies included in trend analysis - anglian water excluded due to its anomalously high 72.1% coverage expansion (section 6a)
trend_companies = [c for c in national_df['company'].unique() if 'AWS' not in c]  # excludes anglian water

years_national = sorted(national_df['year'].unique())  # list of years for x axis ticks

fig, ax = plt.subplots(figsize=(9, 6))  # creates figure

for company in trend_companies:
    data = national_df[national_df['company'] == company].sort_values('year')
    if 'SWW' in company:
        continue  # SWW plotted last so it renders on top of all grey lines
    ax.plot(data['year'], data['spills_per_monitored_site'], color=COLOUR_NATIONAL, linewidth=1, alpha=0.6)  # one grey line per company

sww_data = national_df[national_df['company'].str.contains('SWW')].sort_values('year')
ax.plot(sww_data['year'], sww_data['spills_per_monitored_site'], color=COLOUR_SWW, linewidth=2.5, label='South West Water')  # SWW drawn last so it sits on top

ax.set_xlabel('year', fontsize=11)  # x axis label
ax.set_ylabel('spills per monitored site', fontsize=11)  # y axis label
ax.set_title('spills per monitored site by water company, 2021–2024\nSouth West Water highlighted, Anglian Water excluded', fontsize=11)  # two line title
ax.set_xticks(years_national)  # ensures only integer years appear on x axis
ax.legend(fontsize=9)  # adds legend
sns.despine(ax=ax)  # removes top and right chart borders

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale3_national_trends.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale3_national_trends.png')
# Out:
# Saved: outputs/scale3_national_trends.png

# %%
# interactive plotly version of the section 6d raw trend overlay - replicates the matplotlib version above with hover tooltips and legend toggle per company
fig = go.Figure()

for company in trend_companies:
    data = national_df[national_df['company'] == company].sort_values('year')
    if 'SWW' in company:
        continue  # SWW plotted last so it renders on top of all grey lines
    fig.add_trace(go.Scatter(
        x=data['year'], # year on x axis
        y=data['spills_per_monitored_site'], # spills per monitored site on y axis
        mode='lines', # lines only - no markers
        name='other companies', # all grey lines share one legend entry
        legendgroup='others', # groups all grey lines so one legend click toggles all of them together
        showlegend=(company == trend_companies[0]), # only first grey trace shows in legend - avoids duplicate entries
        line=dict(color=COLOUR_NATIONAL, width=1), # grey colour matched to matplotlib version
        opacity=0.6, # matched to matplotlib alpha
        customdata=[[company]] * len(data), # passes company name into hover via customdata
        hovertemplate='<b>%{customdata[0]}</b><br>year: %{x}<br>spills per monitored site: %{y:.2f}<extra></extra>',)) # hover shows company name, year and value

sww_data = national_df[national_df['company'].str.contains('SWW')].sort_values('year')
fig.add_trace(go.Scatter(
    x=sww_data['year'], # year on x axis
    y=sww_data['spills_per_monitored_site'], # spills per monitored site on y axis
    mode='lines', # lines only - no markers
    name='South West Water', # separate legend entry for SWW
    legendgroup='sww', # SWW in its own legend group
    line=dict(color=COLOUR_SWW, width=2.5), # orange colour and heavier line weight matched to matplotlib version
    hovertemplate='<b>South West Water</b><br>year: %{x}<br>spills per monitored site: %{y:.2f}<extra></extra>',)) # hover shows SWW name, year and value

fig.update_layout(
    title='spills per monitored site by water company, 2021–2024<br><sup>South West Water highlighted, Anglian Water excluded</sup>', # matches matplotlib title
    xaxis_title='year', # matches matplotlib x axis label
    yaxis_title='spills per monitored site', # matches matplotlib y axis label
    height=500, # height in pixels
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    legend=dict(font=dict(size=9)),) # legend font size matched to matplotlib version

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', tickvals=years_national) # integer year ticks only - matches matplotlib set_xticks
fig.update_yaxes(showgrid=True, gridcolor='#e5e5e5') # light grey grid lines on y axis

print('The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.
# ...

# %% [markdown]
# > finding: all eight companies show a synchronised dip in 2022 followed by a sharp rise in 2023 - confirming that 2022 was a nationally dry year that reduced spills across the entire sector rather than reflecting genuine infrastructure improvement at any individual company
# > finding: SWW starts and remains elevated throughout - sitting in the upper half of the distribution in every year - but the shared V-shape pattern makes it difficult to separate company specific trajectory from the national weather signal in the raw chart alone

# %%
# indexed overlay - each company rebased to 100 in 2021, showing percentage change from baseline - removes the effect of different starting levels and makes trajectories directly comparable
fig, ax = plt.subplots(figsize=(9, 6))  # creates figure

for company in trend_companies:
    data = national_df[national_df['company'] == company].sort_values('year').copy()
    base = data.loc[data['year'] == 2021, 'spills_per_monitored_site'].values[0]  # 2021 value as baseline
    data['indexed'] = (data['spills_per_monitored_site'] / base) * 100  # rebases each company to 100 in 2021
    if 'SWW' in company:
        continue  # SWW plotted last so it renders on top of all grey lines
    ax.plot(data['year'], data['indexed'], color=COLOUR_NATIONAL, linewidth=1, alpha=0.6)  # one grey line per company

sww_data = national_df[national_df['company'].str.contains('SWW')].sort_values('year').copy()
sww_base = sww_data.loc[sww_data['year'] == 2021, 'spills_per_monitored_site'].values[0]  # SWW 2021 baseline
sww_data['indexed'] = (sww_data['spills_per_monitored_site'] / sww_base) * 100  # rebases SWW to 100 in 2021
ax.plot(sww_data['year'], sww_data['indexed'], color=COLOUR_SWW, linewidth=2.5, label='South West Water')  # SWW drawn last so it sits on top

ax.axhline(100, color='black', linewidth=0.8, linestyle='--')  # reference line at 100 - above means worse than 2021, below means better
ax.set_xlabel('year', fontsize=11)  # x axis label
ax.set_ylabel('index (2021 = 100)', fontsize=11)  # y axis label
ax.set_title('spills per monitored site by water company, 2021–2024\nindexed to 2021 = 100, Anglian Water excluded', fontsize=11)  # two line title
ax.set_xticks(years_national)  # ensures only integer years appear on x axis
ax.legend(fontsize=9)  # adds legend
sns.despine(ax=ax)  # removes top and right chart borders

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale3_national_trends_indexed.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale3_national_trends_indexed.png')
# Out:
# Saved: outputs/scale3_national_trends_indexed.png

# %%
# interactive plotly version of the section 6d indexed overlay - replicates the matplotlib version above with hover tooltips and legend toggle per company
fig = go.Figure()

for company in trend_companies:
    data = national_df[national_df['company'] == company].sort_values('year').copy()
    base = data.loc[data['year'] == 2021, 'spills_per_monitored_site'].values[0] # 2021 value as baseline
    data['indexed'] = (data['spills_per_monitored_site'] / base) * 100 # rebases each company to 100 in 2021
    if 'SWW' in company:
        continue  # SWW plotted last so it renders on top of all grey lines
    fig.add_trace(go.Scatter(
        x=data['year'], # year on x axis
        y=data['indexed'], # indexed value on y axis
        mode='lines', # lines only - no markers
        name='other companies', # all grey lines share one legend entry
        legendgroup='others', # groups all grey lines so one legend click toggles all of them together
        showlegend=(company == trend_companies[0]), # only first grey trace shows in legend - avoids duplicate entries
        line=dict(color=COLOUR_NATIONAL, width=1), # grey colour matched to matplotlib version
        opacity=0.6, # matched to matplotlib alpha
        customdata=[[company]] * len(data), # passes company name into hover via customdata
        hovertemplate='<b>%{customdata[0]}</b><br>year: %{x}<br>index: %{y:.2f}<extra></extra>', # hover shows company name, year, and indexed value
    ))

sww_data = national_df[national_df['company'].str.contains('SWW')].sort_values('year').copy()
sww_base = sww_data.loc[sww_data['year'] == 2021, 'spills_per_monitored_site'].values[0] # SWW 2021 baseline
sww_data['indexed'] = (sww_data['spills_per_monitored_site'] / sww_base) * 100 # rebases SWW to 100 in 2021
fig.add_trace(go.Scatter(
    x=sww_data['year'], # year on x axis
    y=sww_data['indexed'], # indexed value on y axis
    mode='lines', # lines only - no markers
    name='South West Water', # separate legend entry for SWW
    legendgroup='sww', # SWW in its own legend group
    line=dict(color=COLOUR_SWW, width=2.5), # orange colour and heavier line weight matched to matplotlib version
    hovertemplate='<b>South West Water</b><br>year: %{x}<br>index: %{y:.2f}<extra></extra>', # hover shows SWW name, year, and indexed value
))

fig.add_hline(y=100, line_dash='dash', line_color='black', line_width=0.8) # reference line at 100 - above means worse than 2021, below means better

fig.update_layout(
    title='spills per monitored site by water company, 2021–2024<br><sup>indexed to 2021 = 100, Anglian Water excluded</sup>', # matches matplotlib title
    xaxis_title='year', # matches matplotlib x axis label
    yaxis_title='index (2021 = 100)', # matches matplotlib y axis label
    height=500, # height in pixels
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    legend=dict(font=dict(size=9)),) # legend font size matched to matplotlib version

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', tickvals=years_national) # integer year ticks only - matches matplotlib set_xticks
fig.update_yaxes(showgrid=True, gridcolor='#e5e5e5') # light grey grid lines on y axis

print('The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.
# ...

# %% [markdown]
# > finding: indexed to a common 2021 baseline, the universal synchronised dip in 2022 is even clearer - every company falls below 100 before recovering in 2023, consistent with a shared national weather effect rather than any company specific change
# > finding: SWWs indexed trajectory broadly follows the group - it is neither the strongest riser nor the flattest line>companies reaching 140-150 by 2023-2024 are likely often starting from lower 2021 baselines, which amplifies their percentage swings relative to companies like SWW that began the period already elevated

# %%
# rainfall adjusted residuals overlay - fits spills_per_monitored_site ~ annual_rainfall_mm per company, takes residuals, plots residual trajectories - residual represents spills above or below what each companys annual rainfall in that year predicts
national_resid_records = []
for company in trend_companies:
    data = national_df[national_df['company'] == company].sort_values('year').copy()
    if data['annual_rainfall_mm'].nunique() < 2:
        continue  # skips companies with no variation in rainfall - cannot fit OLS
    rain_model = smf.ols('spills_per_monitored_site ~ annual_rainfall_mm', data=data).fit()  # fits within company rainfall regression
    data['rain_residual'] = rain_model.resid  # residual = actual spills minus rainfall predicted spills
    national_resid_records.append(data[['company', 'year', 'rain_residual']])

national_resid_df = pd.concat(national_resid_records, ignore_index=True)  # combines all companies into one long dataframe

fig, ax = plt.subplots(figsize=(9, 6))  # creates figure

for company, group in national_resid_df.groupby('company'):
    data = group.sort_values('year')
    if 'SWW' in company:
        continue  # SWW plotted last so it renders on top of all grey lines
    ax.plot(data['year'], data['rain_residual'], color=COLOUR_NATIONAL, linewidth=1, alpha=0.6)  # one grey line per company

sww_resid = national_resid_df[national_resid_df['company'].str.contains('SWW')].sort_values('year')
ax.plot(sww_resid['year'], sww_resid['rain_residual'], color=COLOUR_SWW, linewidth=2.5, label='South West Water')  # SWW drawn last so it sits on top

ax.axhline(0, color='black', linewidth=0.8, linestyle='--')  # reference line at zero - above means more spills than rainfall predicts, below means fewer
ax.set_xlabel('year', fontsize=11)  # x axis label
ax.set_ylabel('residual spills per monitored site (rainfall-adjusted)', fontsize=11)  # y axis label
ax.set_title('rainfall-adjusted spills per monitored site by water company, 2021–2024\nper-company OLS residuals after controlling for annual_rainfall_mm, Anglian Water excluded', fontsize=11)  # two line title
ax.set_xticks(years_national)  # ensures only integer years appear on x axis
ax.legend(fontsize=9)  # adds legend
sns.despine(ax=ax)  # removes top and right chart borders

plt.tight_layout()
plt.savefig(os.path.join(OUTPUTS_DIR, 'scale3_national_trends_adjusted.png'), dpi=150, bbox_inches='tight')
plt.close()  # closes without displaying - static version saved to outputs/ for hackmd embedding, interactive plotly version shown below
print('Saved: outputs/scale3_national_trends_adjusted.png')
# Out:
# Saved: outputs/scale3_national_trends_adjusted.png

# %%
# interactive plotly version of the section 6d rainfall adjusted residuals overlay - replicates the matplotlib version above with hover tooltips and legend toggle per company
fig = go.Figure()

for company, group in national_resid_df.groupby('company'):
    data = group.sort_values('year')
    if 'SWW' in company:
        continue  # SWW plotted last so it renders on top of all grey lines
    fig.add_trace(go.Scatter(
        x=data['year'], # year on x axis
        y=data['rain_residual'], # rainfall-adjusted residual on y axis
        mode='lines', # lines only - no markers
        name='other companies', # all grey lines share one legend entry
        legendgroup='others', # groups all grey lines so one legend click toggles all of them together
        showlegend=(company == national_resid_df['company'].unique()[0]), # only first grey trace shows in legend - avoids duplicate entries
        line=dict(color=COLOUR_NATIONAL, width=1), # grey colour matched to matplotlib version
        opacity=0.6, # matched to matplotlib alpha
        customdata=[[company]] * len(data), # passes company name into hover via customdata
        hovertemplate='<b>%{customdata[0]}</b><br>year: %{x}<br>residual: %{y:.2f}<extra></extra>', # hover shows company name, year and residual value
    ))

sww_resid = national_resid_df[national_resid_df['company'].str.contains('SWW')].sort_values('year')
fig.add_trace(go.Scatter(
    x=sww_resid['year'], # year on x axis
    y=sww_resid['rain_residual'], # rainfall-adjusted residual on y axis
    mode='lines', # lines only - no markers
    name='South West Water', # separate legend entry for SWW
    legendgroup='sww', # SWW in its own legend group
    line=dict(color=COLOUR_SWW, width=2.5), # orange colour and heavier line weight matched to matplotlib version
    hovertemplate='<b>South West Water</b><br>year: %{x}<br>residual: %{y:.2f}<extra></extra>', # hover shows SWW name, year and residual value
))

fig.add_hline(y=0, line_dash='dash', line_color='black', line_width=0.8) # reference line at zero - above means more spills than rainfall predicts

fig.update_layout(
    title='rainfall-adjusted spills per monitored site by water company, 2021–2024<br><sup>per-company OLS residuals after controlling for annual_rainfall_mm, Anglian Water excluded</sup>', # matches matplotlib title
    xaxis_title='year', # matches matplotlib x axis label
    yaxis_title='residual spills per monitored site (rainfall-adjusted)', # matches matplotlib y axis label
    height=500, # height in pixels
    plot_bgcolor='white', # white plot background to match seaborn whitegrid style
    paper_bgcolor='white', # white paper background
    width=700, # constrains chart width to match matplotlib figure width
    legend=dict(font=dict(size=9)),) # legend font size matched to matplotlib version

fig.update_xaxes(showgrid=True, gridcolor='#e5e5e5', tickvals=years_national) # integer year ticks only - matches matplotlib set_xticks
fig.update_yaxes(showgrid=True, gridcolor='#e5e5e5') # light grey grid lines on y axis

print('The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.') # signpost printed directly above the chart output
fig.show()
# Out:
# The chart below is interactive - hover over any line to see exact values, or click a legend entry to show or hide individual series.
# ...

# %%
# prints all companies sorted by their 2022 rainfall adjusted residual - identifies which company is the extreme outlier visible in the chart above
print(national_resid_df[national_resid_df['year'] == 2022].sort_values('rain_residual'))
# Out:
#                      company  year  rain_residual
# 17         Thames Water (TW)  2022      -5.859338
# 9     South West Water (SWW)  2022      -2.148461
# 5   Severn Trent Water (SvT)  2022      -1.878669
# 29     Yorkshire Water (YWS)  2022      -1.469842
# 21     United Utilities (UU)  2022      -0.861125
# 1    Northumbrian Water (NW)  2022      -0.488221
# 13       Southern Water (SW)  2022       0.092637
# 25       Wessex Water (WSSX)  2022       0.476635

# %% [markdown]
# > finding: thames water is a clear outlier in the adjusted chart - its 2022 residual of -5.86 spills per monitored site is far below every other company, meaning its spills in 2022 were substantially lower than its regional rainfall alone would predict>it recovers sharply in subsequent years
# > finding: the 2022 dip persists for most companies even after rainfall adjustment - the within company OLS has not successfully removed the entire shared weather signal>this reflects two limitations: with only four data points per company the OLS has little explanatory power, and annual total rainfall mm is a much weaker proxy for overflow activating storm pressure than the storm_days measure available at scales 1 and 2>the adjusted chart should be read as a partial rather than complete weather correction
# > finding: the between company residual ranking from section 6b remains more reliable than the within company trend adjustment here - every company is proxied by the same imperfect rainfall measure, so relative cross sectional comparisons are internally consistent even where the temporal adjustment is weak

# %%
# fits raw slope and rainfall adjusted slope per company
national_trend_records = []
for company in trend_companies:
    data = national_df[national_df['company'] == company].sort_values('year').copy()

    raw_model = smf.ols('spills_per_monitored_site ~ year', data=data).fit()  # raw trend slope
    raw_slope = raw_model.params['year']
    raw_pval = raw_model.pvalues['year']

    rain_model = smf.ols('spills_per_monitored_site ~ annual_rainfall_mm', data=data).fit()  # within company rainfall regression
    data['rain_residual'] = rain_model.resid  # residual after stripping within company rainfall variation

    adj_model = smf.ols('rain_residual ~ year', data=data).fit()  # trend fitted on weather adjusted residuals
    adj_slope = adj_model.params['year']
    adj_pval = adj_model.pvalues['year']

    national_trend_records.append({
        'company': company,
        'raw_slope': raw_slope,
        'raw_p_value': raw_pval,
        'adj_slope': adj_slope,
        'adj_p_value': adj_pval})

national_trend_slopes = pd.DataFrame(national_trend_records).sort_values('adj_slope', ascending=False).reset_index(drop=True)  # sorted highest to lowest adjusted slope

print('Scale 3 trend slopes - raw vs rainfall-adjusted, sorted by adjusted slope (most worsening first):')
print(f"{'company':<35} {'raw slope':>10} {'raw p':>8} {'adj slope':>10} {'adj p':>8}")
print('-' * 75)
for _, row in national_trend_slopes.iterrows():
    print(f"{row['company']:<35} {row['raw_slope']:>10.2f} {row['raw_p_value']:>8.3f} {row['adj_slope']:>10.2f} {row['adj_p_value']:>8.3f}")
# Out:
# Scale 3 trend slopes - raw vs rainfall-adjusted, sorted by adjusted slope (most worsening first):
# company                              raw slope    raw p  adj slope    adj p
# ---------------------------------------------------------------------------
# Wessex Water (WSSX)                       4.79    0.167       0.81    0.392
# Southern Water (SW)                       4.29    0.172       0.13    0.493
# Thames Water (TW)                         3.34    0.540      -0.32    0.943
# Northumbrian Water (NW)                   1.27    0.594      -0.50    0.218
# Severn Trent Water (SvT)                  0.85    0.672      -0.77    0.498
# South West Water (SWW)                    2.22    0.568      -1.18    0.383
# Yorkshire Water (YWS)                     0.38    0.889      -1.32    0.243
# United Utilities (UU)                    -1.09    0.731      -2.35    0.338

# %% [markdown]
# > finding: no slope is statistically significant at any conventional threshold - with only four data points per company this is expected and all slopes should be read as indicative of direction only
# > finding: once rainfall is controlled for, six of the eight companies show negative adjusted slopes - but given the weakness of the within company rainfall adjustment demonstrated by the residuals chart above, these adjusted slopes should not be treated as clean structural trend estimates>the direction of travel is suggestive but not conclusive
# > finding: the one consistent picture across both raw and adjusted slopes is that no company shows clear statistically significant worsening over 2021-2024 - the period is simply too short and the weather signal too dominant to draw firm structural conclusions from just the trend analysis at this scale
